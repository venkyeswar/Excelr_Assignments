# %% [markdown]
# # Assignment 10
# ## Association Rules
#
# ## Objective:
#
#  The Objective of this assignment is to perform necessary operations like preprocessing, and Applying the Apriori algorithm to determine the association rules for the given dataset ("Online retail")

# %% [markdown]
# ## Task 1 : Data Preprocessing

# %%
# Import necessary libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the dataset
data = pd.read_excel("online retail.xlsx")

# %%
data
# Out:
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                                burgers,meatballs,eggs
# 1                                               chutney
# 2                                        turkey,avocado
# 3     mineral water,milk,energy bar,whole wheat rice...
# 4                                        low fat yogurt
# ...                                                 ...
# 7495                      butter,light mayo,fresh bread
# 7496  burgers,frozen vegetables,eggs,french fries,ma...
# 7497                                            chicken
# 7498                                 escalope,green tea
# 7499    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [7500 rows x 1 columns]

# %%
data.columns =["items"]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   items   7500 non-null   object
# dtypes: object(1)
# memory usage: 58.7+ KB

# %%
# So the data has no null values.
# we have to use transaction encoder for converting the transaction data into appropriate format.

# Converting the data into list of transactions.
Data = [ trans.split(',') for trans in data['items'] ]

# %%
Data
# Out:
# [['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
#   'low fat yogurt'],
#  ['turkey', 'eggs'],
#  ['turkey',
#   'fresh tuna',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'black tea',
#   'salmon',
#   'eggs',
#   'chicken',
#   'extra dark chocolate'],
#  ['meatballs', 'milk', 'honey', 'french fries', 'protein bar'],
#  ['red wine', 'shrimp', 'pasta', 'pepper', 'eggs', 'chocolate', 'shampoo'],
# ...

# %%
# Applying Transaction Encoder
# !pip install mlxtend

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()

# %%
te_array = te.fit(Data).transform(Data)

# %%
te_array
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False]])

# %%
df = pd.DataFrame(te_array,columns = te.columns_)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Columns: 120 entries,  asparagus to zucchini
# dtypes: bool(120)
# memory usage: 879.0 KB

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Task 2 : Association Rule Mining

# %%
# import apriori algorithm and find the frequent_itemsets

from mlxtend.frequent_patterns import apriori,association_rules

# %%
frequent_itemsets = apriori(df,min_support=0.03, use_colnames=True)

# %%
frequent_itemsets
# Out:
#      support                            itemsets
# 0   0.033200                           (avocado)
# 1   0.033733                          (brownies)
# 2   0.087200                           (burgers)
# 3   0.030133                            (butter)
# 4   0.081067                              (cake)
# 5   0.046800                         (champagne)
# 6   0.060000                           (chicken)
# 7   0.163867                         (chocolate)
# 8   0.080400                           (cookies)
# 9   0.051067                       (cooking oil)
# 10  0.031733                    (cottage cheese)
# 11  0.179733                              (eggs)
# 12  0.079333                          (escalope)
# 13  0.170933                      (french fries)
# 14  0.043067                       (fresh bread)
# 15  0.063200                   (frozen smoothie)
# 16  0.095333                 (frozen vegetables)
# 17  0.052400                     (grated cheese)
# ...

# %%
rules = association_rules(frequent_itemsets,metric="lift",min_threshold=0.5)

# %%
rules.sort_values(by = "confidence")
# Out:
#             antecedents          consequents  antecedent support  \
# 23      (mineral water)          (green tea)            0.238267
# 32      (mineral water)           (pancakes)            0.238267
# 19      (mineral water)       (french fries)            0.238267
# 21      (mineral water)  (frozen vegetables)            0.238267
# 12               (eggs)               (milk)            0.179733
# 24      (mineral water)        (ground beef)            0.238267
# 1                (eggs)          (chocolate)            0.179733
# 4           (chocolate)               (milk)            0.163867
# 18       (french fries)      (mineral water)            0.170933
# 3        (french fries)          (chocolate)            0.170933
# 28      (mineral water)               (milk)            0.238267
# 10               (eggs)       (french fries)            0.179733
# 0           (chocolate)               (eggs)            0.163867
# ...

# %% [markdown]
# ## Task 3 : Analysis and Interpretation:
#
# (chocolate) → (eggs)
#
# **Support**: 3.32% of transactions contain both chocolate and eggs.
#
# **Confidence**: 20.26% of transactions that contain chocolate also contain eggs.
#
# **Lift**: 1.13, meaning that chocolate increases the likelihood of eggs being purchased by about 13% compared to random chance.
#
# (chocolate) → (french fries)
#
# **Support**: 3.44% of transactions contain both chocolate and french fries.
#
# **Confidence**: 20.99% of transactions that contain chocolate also contain french fries.
#
# **Lift**: 1.23, indicating a stronger association between chocolate and french fries compared to the previous rule.
#
# (milk) → (chocolate)
#
# **Support**: 3.21% of transactions contain both milk and chocolate.
#
# **Confidence**: 24.79% of transactions that contain milk also contain chocolate.
#
# **Lift**: 1.51, indicating a much stronger association between milk and chocolate.

# %%
## Saving the Association Rules 
rules.to_csv("rules.csv")

# %%
# Out:
#             antecedents          consequents  antecedent support  \
# 0           (chocolate)               (eggs)            0.163867
# 1                (eggs)          (chocolate)            0.179733
# 2           (chocolate)       (french fries)            0.163867
# 3        (french fries)          (chocolate)            0.170933
# 4           (chocolate)               (milk)            0.163867
# 5                (milk)          (chocolate)            0.129600
# 6           (chocolate)      (mineral water)            0.163867
# 7       (mineral water)          (chocolate)            0.238267
# 8           (chocolate)          (spaghetti)            0.163867
# 9           (spaghetti)          (chocolate)            0.174133
# 10               (eggs)       (french fries)            0.179733
# 11       (french fries)               (eggs)            0.170933
# 12               (eggs)               (milk)            0.179733
# ...

# %% [markdown]
# ## Interview questions :
# ### 1.	What is lift and why is it important in Association rules?
#
#    **Lift** : lift is the ratio of the observed support to that expected if X and Y are independent .
#    it measures how much more likely the consequent is given the antcecedent compared to its typical occurances.
#
# ### 2. what is support and Confidence, how do you calculate them ?
#
#    **Support** : measures how frequently the itemset appears in the dataset.
#
#    **support** (X) = no.of transactions contain X/ total no.of transactions.
#
#    **Confidence** : the probability that a transaction containing antecedent also contains the consequent.
#
#    **confidence**(x-->y) = support(XUY)/support(x)
#
# ### 3. What are some limitations or challenges of Association mining ?
#
# 1. Too Many Rules : It generates large number of rules, many of them are irrelevant and uninteresting.
# 2. Support for Rare Items : items with low frequency may be overlooked, even if they have strong associations.
# 3. Difficulty in Setting Threshold values.
