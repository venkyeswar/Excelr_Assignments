# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import sqrt
import itertools
import warnings
warnings.filterwarnings('ignore')

# %%
rate = pd.read_csv('/content/exchange_rate.csv')

# %%
rate
# Out:
#                   date   Ex_rate
# 0     01-01-1990 00:00  0.785500
# 1     02-01-1990 00:00  0.781800
# 2     03-01-1990 00:00  0.786700
# 3     04-01-1990 00:00  0.786000
# 4     05-01-1990 00:00  0.784900
# ...                ...       ...
# 7583  06-10-2010 00:00  0.718494
# 7584  07-10-2010 00:00  0.721839
# 7585  08-10-2010 00:00  0.723197
# 7586  09-10-2010 00:00  0.720825
# 7587  10-10-2010 00:00  0.720825
#
# [7588 rows x 2 columns]

# %%
exrate = rate.copy()

# %%
# Convert the datetime column
exrate['date'] = pd.to_datetime(exrate['date'], format='%d-%m-%Y') # Changed format string to match the date format in your data

# %%
# Create a new column with only the date part# 
exrate['date'] = exrate['date'].dt.strftime('%Y-%m-%d')

# %%
#save the updated datset
exrate.to_csv('exrate.csv',index=False)

# %%
print(exrate.head())
# Out:
#          date  Ex_rate
# 0  1990-01-01   0.7855
# 1  1990-01-02   0.7818
# 2  1990-01-03   0.7867
# 3  1990-01-04   0.7860
# 4  1990-01-05   0.7849

# %%
exrate.columns
# Out:
# Index(['date', 'Ex_rate'], dtype='object')

# %%
exrate.describe()
# Out:
#            Ex_rate
# count  7588.000000
# mean      0.776974
# std       0.136620
# min       0.483297
# 25%       0.701422
# 50%       0.761377
# 75%       0.873477
# max       1.102536

# %%
exrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7588 entries, 0 to 7587
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     7588 non-null   object
#  1   Ex_rate  7588 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 118.7+ KB

# %%
exrate.isnull().sum()
# Out:
# date       0
# Ex_rate    0
# dtype: int64

# %%
sns.heatmap(exrate.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
exrate.duplicated().sum()
# Out:
# 0

# %% [markdown]
# IN the above dataset there are no null values and duplicate values.

# %%
#line plot of time series
from matplotlib import pyplot
exrate.plot(x='date',y='Ex_rate',kind='line')
pyplot.show()

# %%
exrate.hist()
# Out:
# array([[<Axes: title={'center': 'Ex_rate'}>]], dtype=object)

# %%
exrate.plot(kind='box',subplots=True,layout=(2,2),sharex=False)
# Out:
# Ex_rate    Axes(0.125,0.53;0.352273x0.35)
# dtype: object

# %%
exrate.plot(kind='density',subplots=True,layout=(2,2),sharex=False)
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %%
exrate.plot(kind='area',subplots=True,layout=(2,2),sharex=False )
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
exrate.plot(kind='line')
# Out:
# <Axes: >

# %%
#seperate out a validation dataset to provide and is used to split a time series dataset into a training set
split_point = len(exrate) - 365
dataset, validation = exrate[0:split_point], exrate[split_point:]
print('Dataset %d, Validation %d' % (len(dataset), len(validation)))
dataset.to_csv('dataset.csv', header=False)
validation.to_csv('validation.csv', header=False)
# Out:
# Dataset 7223, Validation 365

# %% [markdown]
# **Base Model/ Persistence**

# %%
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from math import sqrt

# Load data
train = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True)

# Ensure that the index is properly parsed as datetime (if needed)
train.index = pd.to_datetime(train.index)

# Select only numeric data for conversion
numeric_data = train.select_dtypes(include=['float64', 'int64'])
X = numeric_data.values
X = X.astype('float32')

# Split data
train_size = int(len(X) * 0.50)  # Use 50% of the data for training
train_data, test_data = X[0:train_size], X[train_size:]

# %%
# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    yhat = history[-1]
    predictions.append(yhat)
# observation
    obs = test[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%.3f' % (yhat, obs))
# report performance
rmse = sqrt(mean_squared_error(test, predictions))
print('RMSE: %.3f' % rmse)
# Out:
# >Predicted=2.000, Expected=0.872
# >Predicted=0.872, Expected=0.868
# >Predicted=0.868, Expected=0.866
# >Predicted=0.866, Expected=0.866
# >Predicted=0.866, Expected=0.878
# >Predicted=0.878, Expected=0.891
# >Predicted=0.891, Expected=0.888
# >Predicted=0.888, Expected=0.908
# >Predicted=0.908, Expected=0.902
# >Predicted=0.902, Expected=0.903
# >Predicted=0.903, Expected=0.903
# >Predicted=0.903, Expected=0.907
# >Predicted=0.907, Expected=0.907
# >Predicted=0.907, Expected=0.913
# >Predicted=0.913, Expected=0.919
# >Predicted=0.919, Expected=0.916
# >Predicted=0.916, Expected=0.916
# >Predicted=0.916, Expected=0.916
# >Predicted=0.916, Expected=0.927
# >Predicted=0.927, Expected=0.920
# >Predicted=0.920, Expected=0.929
# >Predicted=0.929, Expected=0.924
# >Predicted=0.924, Expected=0.925
# >Predicted=0.925, Expected=0.922
# >Predicted=0.922, Expected=0.922
# >Predicted=0.922, Expected=0.919
# >Predicted=0.919, Expected=0.915
# >Predicted=0.915, Expected=0.897
# >Predicted=0.897, Expected=0.916
# >Predicted=0.916, Expected=0.901
# >Predicted=0.901, Expected=0.901
# >Predicted=0.901, Expected=0.901
# >Predicted=0.901, Expected=0.909
# >Predicted=0.909, Expected=0.898
# >Predicted=0.898, Expected=0.909
# >Predicted=0.909, Expected=0.909
# >Predicted=0.909, Expected=0.918
# >Predicted=0.918, Expected=0.918
# >Predicted=0.918, Expected=0.918
# >Predicted=0.918, Expected=0.929
# >Predicted=0.929, Expected=0.928
# >Predicted=0.928, Expected=0.927
# >Predicted=0.927, Expected=0.925
# >Predicted=0.925, Expected=0.931
# >Predicted=0.931, Expected=0.934
# >Predicted=0.934, Expected=0.934
# >Predicted=0.934, Expected=0.937
# >Predicted=0.937, Expected=0.926
# >Predicted=0.926, Expected=0.930
# >Predicted=0.930, Expected=0.916
# >Predicted=0.916, Expected=0.916
# >Predicted=0.916, Expected=0.915
# >Predicted=0.915, Expected=0.915
# >Predicted=0.915, Expected=0.924
# >Predicted=0.924, Expected=0.917
# >Predicted=0.917, Expected=0.928
# >Predicted=0.928, Expected=0.911
# >Predicted=0.911, Expected=0.909
# >Predicted=0.909, Expected=0.908
# >Predicted=0.908, Expected=0.908
# >Predicted=0.908, Expected=0.914
# >Predicted=0.914, Expected=0.925
# >Predicted=0.925, Expected=0.926
# >Predicted=0.926, Expected=0.927
# >Predicted=0.927, Expected=0.915
# >Predicted=0.915, Expected=0.915
# >Predicted=0.915, Expected=0.915
# >Predicted=0.915, Expected=0.913
# >Predicted=0.913, Expected=0.908
# >Predicted=0.908, Expected=0.907
# >Predicted=0.907, Expected=0.917
# >Predicted=0.917, Expected=0.912
# >Predicted=0.912, Expected=0.911
# >Predicted=0.911, Expected=0.911
# >Predicted=0.911, Expected=0.915
# >Predicted=0.915, Expected=0.907
# >Predicted=0.907, Expected=0.901
# >Predicted=0.901, Expected=0.885
# >Predicted=0.885, Expected=0.886
# >Predicted=0.886, Expected=0.891
# >Predicted=0.891, Expected=0.891
# >Predicted=0.891, Expected=0.883
# >Predicted=0.883, Expected=0.877
# >Predicted=0.877, Expected=0.881
# >Predicted=0.881, Expected=0.883
# >Predicted=0.883, Expected=0.885
# >Predicted=0.885, Expected=0.885
# >Predicted=0.885, Expected=0.885
# >Predicted=0.885, Expected=0.887
# >Predicted=0.887, Expected=0.896
# >Predicted=0.896, Expected=0.894
# >Predicted=0.894, Expected=0.898
# >Predicted=0.898, Expected=0.898
# >Predicted=0.898, Expected=0.898
# >Predicted=0.898, Expected=0.898
# >Predicted=0.898, Expected=0.913
# >Predicted=0.913, Expected=0.912
# >Predicted=0.912, Expected=0.919
# >Predicted=0.919, Expected=0.917
# >Predicted=0.917, Expected=0.921
# >Predicted=0.921, Expected=0.925
# >Predicted=0.925, Expected=0.925
# >Predicted=0.925, Expected=0.929
# >Predicted=0.929, Expected=0.924
# >Predicted=0.924, Expected=0.921
# >Predicted=0.921, Expected=0.930
# >Predicted=0.930, Expected=0.923
# >Predicted=0.923, Expected=0.923
# >Predicted=0.923, Expected=0.923
# >Predicted=0.923, Expected=0.927
# >Predicted=0.927, Expected=0.923
# >Predicted=0.923, Expected=0.908
# >Predicted=0.908, Expected=0.905
# >Predicted=0.905, Expected=0.905
# >Predicted=0.905, Expected=0.904
# >Predicted=0.904, Expected=0.901
# >Predicted=0.901, Expected=0.904
# >Predicted=0.904, Expected=0.901
# >Predicted=0.901, Expected=0.897
# >Predicted=0.897, Expected=0.896
# >Predicted=0.896, Expected=0.888
# >Predicted=0.888, Expected=0.884
# >Predicted=0.884, Expected=0.884
# >Predicted=0.884, Expected=0.888
# >Predicted=0.888, Expected=0.884
# >Predicted=0.884, Expected=0.882
# >Predicted=0.882, Expected=0.866
# >Predicted=0.866, Expected=0.862
# >Predicted=0.862, Expected=0.862
# >Predicted=0.862, Expected=0.862
# >Predicted=0.862, Expected=0.870
# >Predicted=0.870, Expected=0.877
# >Predicted=0.877, Expected=0.873
# >Predicted=0.873, Expected=0.889
# >Predicted=0.889, Expected=0.884
# >Predicted=0.884, Expected=0.887
# >Predicted=0.887, Expected=0.887
# >Predicted=0.887, Expected=0.890
# >Predicted=0.890, Expected=0.899
# >Predicted=0.899, Expected=0.900
# >Predicted=0.900, Expected=0.897
# >Predicted=0.897, Expected=0.894
# >Predicted=0.894, Expected=0.895
# >Predicted=0.895, Expected=0.895
# >Predicted=0.895, Expected=0.899
# >Predicted=0.899, Expected=0.894
# >Predicted=0.894, Expected=0.894
# >Predicted=0.894, Expected=0.881
# >Predicted=0.881, Expected=0.896
# >Predicted=0.896, Expected=0.896
# >Predicted=0.896, Expected=0.896
# >Predicted=0.896, Expected=0.900
# >Predicted=0.900, Expected=0.904
# >Predicted=0.904, Expected=0.907
# >Predicted=0.907, Expected=0.900
# >Predicted=0.900, Expected=0.907
# >Predicted=0.907, Expected=0.906
# >Predicted=0.906, Expected=0.906
# >Predicted=0.906, Expected=0.908
# >Predicted=0.908, Expected=0.913
# >Predicted=0.913, Expected=0.916
# >Predicted=0.916, Expected=0.915
# >Predicted=0.915, Expected=0.915
# >Predicted=0.915, Expected=0.915
# >Predicted=0.915, Expected=0.915
# >Predicted=0.915, Expected=0.912
# >Predicted=0.912, Expected=0.915
# >Predicted=0.915, Expected=0.923
# >Predicted=0.923, Expected=0.920
# >Predicted=0.920, Expected=0.916
# >Predicted=0.916, Expected=0.916
# >Predicted=0.916, Expected=0.916
# >Predicted=0.916, Expected=0.917
# >Predicted=0.917, Expected=0.917
# >Predicted=0.917, Expected=0.910
# >Predicted=0.910, Expected=0.913
# >Predicted=0.913, Expected=0.902
# >Predicted=0.902, Expected=0.902
# >Predicted=0.902, Expected=0.902
# >Predicted=0.902, Expected=0.915
# >Predicted=0.915, Expected=0.919
# >Predicted=0.919, Expected=0.918
# >Predicted=0.918, Expected=0.920
# >Predicted=0.920, Expected=0.919
# >Predicted=0.919, Expected=0.919
# >Predicted=0.919, Expected=0.919
# >Predicted=0.919, Expected=0.920
# >Predicted=0.920, Expected=0.925
# >Predicted=0.925, Expected=0.929
# >Predicted=0.929, Expected=0.928
# >Predicted=0.928, Expected=0.932
# >Predicted=0.932, Expected=0.933
# >Predicted=0.933, Expected=0.933
# >Predicted=0.933, Expected=0.929
# >Predicted=0.929, Expected=0.928
# >Predicted=0.928, Expected=0.935
# >Predicted=0.935, Expected=0.933
# >Predicted=0.933, Expected=0.924
# >Predicted=0.924, Expected=0.925
# >Predicted=0.925, Expected=0.925
# >Predicted=0.925, Expected=0.920
# >Predicted=0.920, Expected=0.930
# >Predicted=0.930, Expected=0.929
# >Predicted=0.929, Expected=0.927
# >Predicted=0.927, Expected=0.925
# >Predicted=0.925, Expected=0.928
# >Predicted=0.928, Expected=0.928
# >Predicted=0.928, Expected=0.926
# >Predicted=0.926, Expected=0.919
# >Predicted=0.919, Expected=0.923
# >Predicted=0.923, Expected=0.928
# >Predicted=0.928, Expected=0.927
# >Predicted=0.927, Expected=0.931
# >Predicted=0.931, Expected=0.931
# >Predicted=0.931, Expected=0.926
# >Predicted=0.926, Expected=0.911
# >Predicted=0.911, Expected=0.908
# >Predicted=0.908, Expected=0.891
# >Predicted=0.891, Expected=0.890
# >Predicted=0.890, Expected=0.890
# >Predicted=0.890, Expected=0.897
# >Predicted=0.897, Expected=0.900
# >Predicted=0.900, Expected=0.901
# >Predicted=0.901, Expected=0.892
# >Predicted=0.892, Expected=0.900
# >Predicted=0.900, Expected=0.886
# >Predicted=0.886, Expected=0.886
# >Predicted=0.886, Expected=0.889
# >Predicted=0.889, Expected=0.870
# >Predicted=0.870, Expected=0.868
# >Predicted=0.868, Expected=0.846
# >Predicted=0.846, Expected=0.817
# >Predicted=0.817, Expected=0.828
# >Predicted=0.828, Expected=0.832
# >Predicted=0.832, Expected=0.830
# >Predicted=0.830, Expected=0.832
# >Predicted=0.832, Expected=0.814
# >Predicted=0.814, Expected=0.832
# >Predicted=0.832, Expected=0.849
# >Predicted=0.849, Expected=0.845
# >Predicted=0.845, Expected=0.847
# >Predicted=0.847, Expected=0.849
# >Predicted=0.849, Expected=0.845
# >Predicted=0.845, Expected=0.841
# >Predicted=0.841, Expected=0.834
# >Predicted=0.834, Expected=0.839
# >Predicted=0.839, Expected=0.825
# >Predicted=0.825, Expected=0.828
# >Predicted=0.828, Expected=0.828
# >Predicted=0.828, Expected=0.817
# >Predicted=0.817, Expected=0.820
# >Predicted=0.820, Expected=0.831
# >Predicted=0.831, Expected=0.848
# >Predicted=0.848, Expected=0.847
# >Predicted=0.847, Expected=0.851
# >Predicted=0.851, Expected=0.849
# >Predicted=0.849, Expected=0.860
# >Predicted=0.860, Expected=0.863
# >Predicted=0.863, Expected=0.865
# >Predicted=0.865, Expected=0.866
# >Predicted=0.866, Expected=0.870
# >Predicted=0.870, Expected=0.870
# >Predicted=0.870, Expected=0.872
# >Predicted=0.872, Expected=0.878
# >Predicted=0.878, Expected=0.878
# >Predicted=0.878, Expected=0.873
# >Predicted=0.873, Expected=0.871
# >Predicted=0.871, Expected=0.874
# >Predicted=0.874, Expected=0.874
# >Predicted=0.874, Expected=0.875
# >Predicted=0.875, Expected=0.872
# >Predicted=0.872, Expected=0.851
# >Predicted=0.851, Expected=0.847
# >Predicted=0.847, Expected=0.842
# >Predicted=0.842, Expected=0.842
# >Predicted=0.842, Expected=0.843
# >Predicted=0.843, Expected=0.843
# >Predicted=0.843, Expected=0.839
# >Predicted=0.839, Expected=0.850
# >Predicted=0.850, Expected=0.865
# >Predicted=0.865, Expected=0.873
# >Predicted=0.873, Expected=0.875
# >Predicted=0.875, Expected=0.878
# >Predicted=0.878, Expected=0.878
# >Predicted=0.878, Expected=0.875
# >Predicted=0.875, Expected=0.880
# >Predicted=0.880, Expected=0.882
# >Predicted=0.882, Expected=0.881
# >Predicted=0.881, Expected=0.869
# >Predicted=0.869, Expected=0.870
# >Predicted=0.870, Expected=0.870
# >Predicted=0.870, Expected=0.869
# >Predicted=0.869, Expected=0.883
# >Predicted=0.883, Expected=0.884
# >Predicted=0.884, Expected=0.893
# >Predicted=0.893, Expected=0.895
# >Predicted=0.895, Expected=0.894
# >Predicted=0.894, Expected=0.895
# >Predicted=0.895, Expected=0.903
# >Predicted=0.903, Expected=0.901
# >Predicted=0.901, Expected=0.894
# >Predicted=0.894, Expected=0.901
# >Predicted=0.901, Expected=0.903
# >Predicted=0.903, Expected=0.905
# >Predicted=0.905, Expected=0.905
# >Predicted=0.905, Expected=0.911
# >Predicted=0.911, Expected=0.914
# >Predicted=0.914, Expected=0.915
# >Predicted=0.915, Expected=0.914
# >Predicted=0.914, Expected=0.916
# >Predicted=0.916, Expected=0.916
# >Predicted=0.916, Expected=0.919
# >Predicted=0.919, Expected=0.916
# >Predicted=0.916, Expected=0.909
# >Predicted=0.909, Expected=0.899
# >Predicted=0.899, Expected=0.895
# >Predicted=0.895, Expected=0.896
# >Predicted=0.896, Expected=0.893
# >Predicted=0.893, Expected=0.895
# >Predicted=0.895, Expected=0.898
# >Predicted=0.898, Expected=0.907
# >Predicted=0.907, Expected=0.901
# >Predicted=0.901, Expected=0.892
# >Predicted=0.892, Expected=0.891
# >Predicted=0.891, Expected=0.894
# >Predicted=0.894, Expected=0.888
# >Predicted=0.888, Expected=0.890
# >Predicted=0.890, Expected=0.884
# >Predicted=0.884, Expected=0.881
# >Predicted=0.881, Expected=0.887
# >Predicted=0.887, Expected=0.897
# >Predicted=0.897, Expected=0.899
# >Predicted=0.899, Expected=0.898
# >Predicted=0.898, Expected=0.894
# >Predicted=0.894, Expected=0.890
# >Predicted=0.890, Expected=0.908
# >Predicted=0.908, Expected=0.909
# >Predicted=0.909, Expected=0.916
# >Predicted=0.916, Expected=0.916
# >Predicted=0.916, Expected=0.917
# >Predicted=0.917, Expected=0.917
# >Predicted=0.917, Expected=0.913
# >Predicted=0.913, Expected=0.918
# >Predicted=0.918, Expected=0.924
# >Predicted=0.924, Expected=0.926
# >Predicted=0.926, Expected=0.926
# >Predicted=0.926, Expected=0.926
# >Predicted=0.926, Expected=0.934
# >Predicted=0.934, Expected=0.943
# >Predicted=0.943, Expected=0.940
# >Predicted=0.940, Expected=0.934
# >Predicted=0.934, Expected=0.939
# >Predicted=0.939, Expected=0.938
# >Predicted=0.938, Expected=0.938
# >Predicted=0.938, Expected=0.948
# >Predicted=0.948, Expected=0.947
# >Predicted=0.947, Expected=0.953
# >Predicted=0.953, Expected=0.953
# >Predicted=0.953, Expected=0.958
# >Predicted=0.958, Expected=0.959
# >Predicted=0.959, Expected=0.958
# >Predicted=0.958, Expected=0.963
# >Predicted=0.963, Expected=0.968
# >Predicted=0.968, Expected=0.970
# >Predicted=0.970, Expected=0.965
# >Predicted=0.965, Expected=0.971
# >Predicted=0.971, Expected=0.973
# >Predicted=0.973, Expected=0.972
# >Predicted=0.972, Expected=0.966
# >Predicted=0.966, Expected=0.969
# >Predicted=0.969, Expected=0.977
# >Predicted=0.977, Expected=0.980
# >Predicted=0.980, Expected=0.985
# >Predicted=0.985, Expected=0.986
# >Predicted=0.986, Expected=0.986
# >Predicted=0.986, Expected=0.985
# >Predicted=0.985, Expected=0.984
# >Predicted=0.984, Expected=0.992
# >Predicted=0.992, Expected=0.993
# >Predicted=0.993, Expected=0.990
# >Predicted=0.990, Expected=0.988
# >Predicted=0.988, Expected=0.988
# >Predicted=0.988, Expected=0.991
# >Predicted=0.991, Expected=0.973
# >Predicted=0.973, Expected=0.986
# >Predicted=0.986, Expected=0.979
# >Predicted=0.979, Expected=0.979
# >Predicted=0.979, Expected=0.983
# >Predicted=0.983, Expected=0.978
# >Predicted=0.978, Expected=0.991
# >Predicted=0.991, Expected=0.985
# >Predicted=0.985, Expected=0.969
# >Predicted=0.969, Expected=0.978
# >Predicted=0.978, Expected=0.981
# >Predicted=0.981, Expected=0.984
# >Predicted=0.984, Expected=0.980
# >Predicted=0.980, Expected=0.986
# >Predicted=0.986, Expected=0.999
# >Predicted=0.999, Expected=0.996
# >Predicted=0.996, Expected=1.014
# >Predicted=1.014, Expected=1.015
# >Predicted=1.015, Expected=1.016
# >Predicted=1.016, Expected=1.016
# >Predicted=1.016, Expected=1.012
# >Predicted=1.012, Expected=1.013
# >Predicted=1.013, Expected=1.003
# >Predicted=1.003, Expected=0.997
# >Predicted=0.997, Expected=0.990
# >Predicted=0.990, Expected=0.984
# >Predicted=0.984, Expected=0.984
# >Predicted=0.984, Expected=0.990
# >Predicted=0.990, Expected=0.975
# >Predicted=0.975, Expected=0.982
# >Predicted=0.982, Expected=0.989
# >Predicted=0.989, Expected=0.985
# >Predicted=0.985, Expected=0.986
# >Predicted=0.986, Expected=0.987
# >Predicted=0.987, Expected=0.986
# >Predicted=0.986, Expected=0.972
# >Predicted=0.972, Expected=0.982
# >Predicted=0.982, Expected=0.981
# >Predicted=0.981, Expected=0.963
# >Predicted=0.963, Expected=0.963
# >Predicted=0.963, Expected=0.964
# >Predicted=0.964, Expected=0.959
# >Predicted=0.959, Expected=0.960
# >Predicted=0.960, Expected=0.976
# >Predicted=0.976, Expected=0.977
# >Predicted=0.977, Expected=0.988
# >Predicted=0.988, Expected=0.988
# >Predicted=0.988, Expected=0.993
# >Predicted=0.993, Expected=0.987
# >Predicted=0.987, Expected=0.989
# >Predicted=0.989, Expected=0.978
# >Predicted=0.978, Expected=0.982
# >Predicted=0.982, Expected=0.985
# >Predicted=0.985, Expected=0.986
# >Predicted=0.986, Expected=0.985
# >Predicted=0.985, Expected=0.994
# >Predicted=0.994, Expected=0.999
# >Predicted=0.999, Expected=0.992
# >Predicted=0.992, Expected=0.986
# >Predicted=0.986, Expected=0.985
# >Predicted=0.985, Expected=0.985
# >Predicted=0.985, Expected=0.989
# >Predicted=0.989, Expected=0.993
# >Predicted=0.993, Expected=0.998
# >Predicted=0.998, Expected=1.000
# >Predicted=1.000, Expected=1.005
# >Predicted=1.005, Expected=1.004
# >Predicted=1.004, Expected=1.006
# >Predicted=1.006, Expected=1.005
# >Predicted=1.005, Expected=1.002
# >Predicted=1.002, Expected=1.011
# >Predicted=1.011, Expected=1.016
# >Predicted=1.016, Expected=1.012
# >Predicted=1.012, Expected=1.024
# >Predicted=1.024, Expected=1.023
# >Predicted=1.023, Expected=1.023
# >Predicted=1.023, Expected=1.020
# >Predicted=1.020, Expected=1.005
# >Predicted=1.005, Expected=1.000
# >Predicted=1.000, Expected=0.995
# >Predicted=0.995, Expected=0.995
# >Predicted=0.995, Expected=0.997
# >Predicted=0.997, Expected=0.996
# >Predicted=0.996, Expected=0.992
# >Predicted=0.992, Expected=0.988
# >Predicted=0.988, Expected=0.993
# >Predicted=0.993, Expected=0.999
# >Predicted=0.999, Expected=0.989
# >Predicted=0.989, Expected=0.989
# >Predicted=0.989, Expected=0.989
# >Predicted=0.989, Expected=0.995
# >Predicted=0.995, Expected=0.998
# >Predicted=0.998, Expected=1.003
# >Predicted=1.003, Expected=0.986
# >Predicted=0.986, Expected=0.989
# >Predicted=0.989, Expected=0.989
# >Predicted=0.989, Expected=0.991
# >Predicted=0.991, Expected=1.000
# >Predicted=1.000, Expected=0.990
# >Predicted=0.990, Expected=0.995
# >Predicted=0.995, Expected=0.990
# >Predicted=0.990, Expected=0.992
# >Predicted=0.992, Expected=0.992
# >Predicted=0.992, Expected=0.995
# >Predicted=0.995, Expected=0.997
# >Predicted=0.997, Expected=1.012
# >Predicted=1.012, Expected=1.007
# >Predicted=1.007, Expected=1.013
# >Predicted=1.013, Expected=1.014
# >Predicted=1.014, Expected=1.014
# >Predicted=1.014, Expected=1.014
# >Predicted=1.014, Expected=1.014
# >Predicted=1.014, Expected=1.017
# >Predicted=1.017, Expected=1.010
# >Predicted=1.010, Expected=1.006
# >Predicted=1.006, Expected=1.000
# >Predicted=1.000, Expected=1.003
# >Predicted=1.003, Expected=1.003
# >Predicted=1.003, Expected=1.002
# >Predicted=1.002, Expected=0.999
# >Predicted=0.999, Expected=0.998
# >Predicted=0.998, Expected=1.011
# >Predicted=1.011, Expected=1.014
# >Predicted=1.014, Expected=1.014
# >Predicted=1.014, Expected=1.015
# >Predicted=1.015, Expected=1.008
# >Predicted=1.008, Expected=0.999
# >Predicted=0.999, Expected=1.000
# >Predicted=1.000, Expected=1.009
# >Predicted=1.009, Expected=1.015
# >Predicted=1.015, Expected=1.015
# >Predicted=1.015, Expected=1.018
# >Predicted=1.018, Expected=1.017
# >Predicted=1.017, Expected=1.017
# >Predicted=1.017, Expected=1.016
# >Predicted=1.016, Expected=1.013
# >Predicted=1.013, Expected=1.012
# >Predicted=1.012, Expected=1.015
# >Predicted=1.015, Expected=1.011
# >Predicted=1.011, Expected=1.011
# >Predicted=1.011, Expected=1.010
# >Predicted=1.010, Expected=1.011
# >Predicted=1.011, Expected=1.001
# >Predicted=1.001, Expected=1.015
# >Predicted=1.015, Expected=1.008
# >Predicted=1.008, Expected=0.991
# >Predicted=0.991, Expected=0.985
# >Predicted=0.985, Expected=0.982
# >Predicted=0.982, Expected=0.995
# >Predicted=0.995, Expected=0.995
# >Predicted=0.995, Expected=0.995
# >Predicted=0.995, Expected=1.005
# >Predicted=1.005, Expected=1.011
# >Predicted=1.011, Expected=1.013
# >Predicted=1.013, Expected=1.021
# >Predicted=1.021, Expected=1.021
# >Predicted=1.021, Expected=1.021
# >Predicted=1.021, Expected=1.021
# >Predicted=1.021, Expected=1.028
# >Predicted=1.028, Expected=1.026
# >Predicted=1.026, Expected=1.033
# >Predicted=1.033, Expected=1.036
# >Predicted=1.036, Expected=1.038
# >Predicted=1.038, Expected=1.038
# >Predicted=1.038, Expected=1.039
# >Predicted=1.039, Expected=1.034
# >Predicted=1.034, Expected=1.034
# >Predicted=1.034, Expected=1.043
# >Predicted=1.043, Expected=1.043
# >Predicted=1.043, Expected=1.055
# >Predicted=1.055, Expected=1.057
# >Predicted=1.057, Expected=1.057
# >Predicted=1.057, Expected=1.052
# >Predicted=1.052, Expected=1.048
# >Predicted=1.048, Expected=1.049
# >Predicted=1.049, Expected=1.053
# >Predicted=1.053, Expected=1.057
# >Predicted=1.057, Expected=1.057
# >Predicted=1.057, Expected=1.056
# >Predicted=1.056, Expected=1.051
# >Predicted=1.051, Expected=1.053
# >Predicted=1.053, Expected=1.067
# >Predicted=1.067, Expected=1.075
# >Predicted=1.075, Expected=1.074
# >Predicted=1.074, Expected=1.074
# >Predicted=1.074, Expected=1.075
# >Predicted=1.075, Expected=1.071
# >Predicted=1.071, Expected=1.077
# >Predicted=1.077, Expected=1.084
# >Predicted=1.084, Expected=1.090
# >Predicted=1.090, Expected=1.096
# >Predicted=1.096, Expected=1.093
# >Predicted=1.093, Expected=1.097
# >Predicted=1.097, Expected=1.096
# >Predicted=1.096, Expected=1.087
# >Predicted=1.087, Expected=1.077
# >Predicted=1.077, Expected=1.062
# >Predicted=1.062, Expected=1.072
# >Predicted=1.072, Expected=1.076
# >Predicted=1.076, Expected=1.069
# >Predicted=1.069, Expected=1.077
# >Predicted=1.077, Expected=1.080
# >Predicted=1.080, Expected=1.068
# >Predicted=1.068, Expected=1.068
# >Predicted=1.068, Expected=1.057
# >Predicted=1.057, Expected=1.058
# >Predicted=1.058, Expected=1.056
# >Predicted=1.056, Expected=1.061
# >Predicted=1.061, Expected=1.058
# >Predicted=1.058, Expected=1.062
# >Predicted=1.062, Expected=1.065
# >Predicted=1.065, Expected=1.070
# >Predicted=1.070, Expected=1.065
# >Predicted=1.065, Expected=1.066
# >Predicted=1.066, Expected=1.051
# >Predicted=1.051, Expected=1.055
# >Predicted=1.055, Expected=1.051
# >Predicted=1.051, Expected=1.061
# >Predicted=1.061, Expected=1.069
# >Predicted=1.069, Expected=1.071
# >Predicted=1.071, Expected=1.071
# >Predicted=1.071, Expected=1.069
# >Predicted=1.069, Expected=1.066
# >Predicted=1.066, Expected=1.068
# >Predicted=1.068, Expected=1.066
# >Predicted=1.066, Expected=1.076
# >Predicted=1.076, Expected=1.072
# >Predicted=1.072, Expected=1.071
# >Predicted=1.071, Expected=1.072
# >Predicted=1.072, Expected=1.073
# >Predicted=1.073, Expected=1.063
# >Predicted=1.063, Expected=1.063
# >Predicted=1.063, Expected=1.054
# >Predicted=1.054, Expected=1.056
# >Predicted=1.056, Expected=1.054
# >Predicted=1.054, Expected=1.057
# >Predicted=1.057, Expected=1.070
# >Predicted=1.070, Expected=1.056
# >Predicted=1.056, Expected=1.053
# >Predicted=1.053, Expected=1.060
# >Predicted=1.060, Expected=1.062
# >Predicted=1.062, Expected=1.063
# >Predicted=1.063, Expected=1.058
# >Predicted=1.058, Expected=1.058
# >Predicted=1.058, Expected=1.063
# >Predicted=1.063, Expected=1.048
# >Predicted=1.048, Expected=1.052
# >Predicted=1.052, Expected=1.052
# >Predicted=1.052, Expected=1.050
# >Predicted=1.050, Expected=1.043
# >Predicted=1.043, Expected=1.051
# >Predicted=1.051, Expected=1.066
# >Predicted=1.066, Expected=1.072
# >Predicted=1.072, Expected=1.078
# >Predicted=1.078, Expected=1.075
# >Predicted=1.075, Expected=1.078
# >Predicted=1.078, Expected=1.073
# >Predicted=1.073, Expected=1.071
# >Predicted=1.071, Expected=1.068
# >Predicted=1.068, Expected=1.077
# >Predicted=1.077, Expected=1.073
# >Predicted=1.073, Expected=1.076
# >Predicted=1.076, Expected=1.073
# >Predicted=1.073, Expected=1.066
# >Predicted=1.066, Expected=1.061
# >Predicted=1.061, Expected=1.076
# >Predicted=1.076, Expected=1.073
# >Predicted=1.073, Expected=1.064
# >Predicted=1.064, Expected=1.066
# >Predicted=1.066, Expected=1.066
# >Predicted=1.066, Expected=1.059
# >Predicted=1.059, Expected=1.073
# >Predicted=1.073, Expected=1.074
# >Predicted=1.074, Expected=1.084
# >Predicted=1.084, Expected=1.085
# >Predicted=1.085, Expected=1.085
# >Predicted=1.085, Expected=1.085
# >Predicted=1.085, Expected=1.086
# >Predicted=1.086, Expected=1.096
# >Predicted=1.096, Expected=1.103
# >Predicted=1.103, Expected=1.102
# >Predicted=1.102, Expected=1.100
# >Predicted=1.100, Expected=1.100
# >Predicted=1.100, Expected=1.100
# >Predicted=1.100, Expected=1.095
# >Predicted=1.095, Expected=1.080
# >Predicted=1.080, Expected=1.075
# >Predicted=1.075, Expected=1.052
# >Predicted=1.052, Expected=1.051
# >Predicted=1.051, Expected=1.038
# >Predicted=1.038, Expected=1.038
# >Predicted=1.038, Expected=1.032
# >Predicted=1.032, Expected=1.014
# >Predicted=1.014, Expected=1.026
# >Predicted=1.026, Expected=1.026
# >Predicted=1.026, Expected=1.036
# >Predicted=1.036, Expected=1.035
# >Predicted=1.035, Expected=1.035
# >Predicted=1.035, Expected=1.049
# >Predicted=1.049, Expected=1.047
# >Predicted=1.047, Expected=1.054
# >Predicted=1.054, Expected=1.034
# >Predicted=1.034, Expected=1.041
# >Predicted=1.041, Expected=1.044
# >Predicted=1.044, Expected=1.044
# >Predicted=1.044, Expected=1.042
# >Predicted=1.042, Expected=1.048
# >Predicted=1.048, Expected=1.046
# >Predicted=1.046, Expected=1.044
# >Predicted=1.044, Expected=1.057
# >Predicted=1.057, Expected=1.058
# >Predicted=1.058, Expected=1.062
# >Predicted=1.062, Expected=1.067
# >Predicted=1.067, Expected=1.074
# >Predicted=1.074, Expected=1.066
# >Predicted=1.066, Expected=1.055
# >Predicted=1.055, Expected=1.063
# >Predicted=1.063, Expected=1.060
# >Predicted=1.060, Expected=1.046
# >Predicted=1.046, Expected=1.028
# >Predicted=1.028, Expected=1.034
# >Predicted=1.034, Expected=1.025
# >Predicted=1.025, Expected=1.036
# >Predicted=1.036, Expected=1.019
# >Predicted=1.019, Expected=1.023
# >Predicted=1.023, Expected=0.975
# >Predicted=0.975, Expected=0.981
# >Predicted=0.981, Expected=0.973
# >Predicted=0.973, Expected=0.998
# >Predicted=0.998, Expected=0.982
# >Predicted=0.982, Expected=0.974
# >Predicted=0.974, Expected=0.961
# >Predicted=0.961, Expected=0.960
# >Predicted=0.960, Expected=0.970
# >Predicted=0.970, Expected=0.976
# >Predicted=0.976, Expected=1.000
# >Predicted=1.000, Expected=0.995
# >Predicted=0.995, Expected=1.019
# >Predicted=1.019, Expected=1.014
# >Predicted=1.014, Expected=1.022
# >Predicted=1.022, Expected=1.024
# >Predicted=1.024, Expected=1.023
# >Predicted=1.023, Expected=1.033
# >Predicted=1.033, Expected=1.045
# >Predicted=1.045, Expected=1.035
# >Predicted=1.035, Expected=1.071
# >Predicted=1.071, Expected=1.059
# >Predicted=1.059, Expected=1.033
# >Predicted=1.033, Expected=1.032
# >Predicted=1.032, Expected=1.038
# >Predicted=1.038, Expected=1.034
# >Predicted=1.034, Expected=1.033
# >Predicted=1.033, Expected=1.033
# >Predicted=1.033, Expected=1.021
# >Predicted=1.021, Expected=1.014
# >Predicted=1.014, Expected=1.029
# >Predicted=1.029, Expected=1.019
# >Predicted=1.019, Expected=1.014
# >Predicted=1.014, Expected=1.014
# >Predicted=1.014, Expected=1.005
# >Predicted=1.005, Expected=1.003
# >Predicted=1.003, Expected=1.001
# >Predicted=1.001, Expected=0.984
# >Predicted=0.984, Expected=0.983
# >Predicted=0.983, Expected=0.969
# >Predicted=0.969, Expected=0.973
# >Predicted=0.973, Expected=0.973
# >Predicted=0.973, Expected=0.992
# >Predicted=0.992, Expected=1.002
# >Predicted=1.002, Expected=1.025
# >Predicted=1.025, Expected=1.022
# >Predicted=1.022, Expected=1.022
# >Predicted=1.022, Expected=1.030
# >Predicted=1.030, Expected=1.022
# >Predicted=1.022, Expected=1.019
# >Predicted=1.019, Expected=1.019
# >Predicted=1.019, Expected=1.019
# >Predicted=1.019, Expected=1.022
# >Predicted=1.022, Expected=1.006
# >Predicted=1.006, Expected=1.009
# >Predicted=1.009, Expected=0.991
# >Predicted=0.991, Expected=0.995
# >Predicted=0.995, Expected=0.998
# >Predicted=0.998, Expected=0.991
# >Predicted=0.991, Expected=1.007
# >Predicted=1.007, Expected=1.006
# >Predicted=1.006, Expected=1.014
# >Predicted=1.014, Expected=1.015
# >Predicted=1.015, Expected=1.016
# >Predicted=1.016, Expected=1.016
# >Predicted=1.016, Expected=1.009
# >Predicted=1.009, Expected=1.011
# >Predicted=1.011, Expected=1.025
# >Predicted=1.025, Expected=1.021
# >Predicted=1.021, Expected=1.021
# >Predicted=1.021, Expected=1.022
# >Predicted=1.022, Expected=1.037
# >Predicted=1.037, Expected=1.023
# >Predicted=1.023, Expected=1.023
# >Predicted=1.023, Expected=1.022
# >Predicted=1.022, Expected=1.033
# >Predicted=1.033, Expected=1.030
# >Predicted=1.030, Expected=1.031
# >Predicted=1.031, Expected=1.030
# >Predicted=1.030, Expected=1.031
# >Predicted=1.031, Expected=1.040
# >Predicted=1.040, Expected=1.046
# >Predicted=1.046, Expected=1.054
# >Predicted=1.054, Expected=1.047
# >Predicted=1.047, Expected=1.048
# >Predicted=1.048, Expected=1.065
# >Predicted=1.065, Expected=1.064
# >Predicted=1.064, Expected=1.058
# >Predicted=1.058, Expected=1.059
# >Predicted=1.059, Expected=1.073
# >Predicted=1.073, Expected=1.072
# >Predicted=1.072, Expected=1.077
# >Predicted=1.077, Expected=1.076
# >Predicted=1.076, Expected=1.073
# >Predicted=1.073, Expected=1.080
# >Predicted=1.080, Expected=1.078
# >Predicted=1.078, Expected=1.080
# >Predicted=1.080, Expected=1.067
# >Predicted=1.067, Expected=1.067
# >Predicted=1.067, Expected=1.074
# >Predicted=1.074, Expected=1.069
# >Predicted=1.069, Expected=1.074
# >Predicted=1.074, Expected=1.075
# >Predicted=1.075, Expected=1.069
# >Predicted=1.069, Expected=1.076
# >Predicted=1.076, Expected=1.069
# >Predicted=1.069, Expected=1.062
# >Predicted=1.062, Expected=1.069
# >Predicted=1.069, Expected=1.071
# >Predicted=1.071, Expected=1.069
# >Predicted=1.069, Expected=1.076
# >Predicted=1.076, Expected=1.076
# >Predicted=1.076, Expected=1.078
# >Predicted=1.078, Expected=1.080
# >Predicted=1.080, Expected=1.074
# >Predicted=1.074, Expected=1.073
# >Predicted=1.073, Expected=1.067
# >Predicted=1.067, Expected=1.054
# >Predicted=1.054, Expected=1.058
# >Predicted=1.058, Expected=1.061
# >Predicted=1.061, Expected=1.059
# >Predicted=1.059, Expected=1.055
# >Predicted=1.055, Expected=1.058
# >Predicted=1.058, Expected=1.048
# >Predicted=1.048, Expected=1.054
# >Predicted=1.054, Expected=1.046
# >Predicted=1.046, Expected=1.055
# >Predicted=1.055, Expected=1.059
# >Predicted=1.059, Expected=1.059
# >Predicted=1.059, Expected=1.060
# >Predicted=1.060, Expected=1.061
# >Predicted=1.061, Expected=1.048
# >Predicted=1.048, Expected=1.045
# >Predicted=1.045, Expected=1.038
# >Predicted=1.038, Expected=1.045
# >Predicted=1.045, Expected=1.046
# >Predicted=1.046, Expected=1.047
# >Predicted=1.047, Expected=1.051
# >Predicted=1.051, Expected=1.049
# >Predicted=1.049, Expected=1.037
# >Predicted=1.037, Expected=1.034
# >Predicted=1.034, Expected=1.038
# >Predicted=1.038, Expected=1.035
# >Predicted=1.035, Expected=1.043
# >Predicted=1.043, Expected=1.037
# >Predicted=1.037, Expected=1.026
# >Predicted=1.026, Expected=1.030
# >Predicted=1.030, Expected=1.031
# >Predicted=1.031, Expected=1.030
# >Predicted=1.030, Expected=1.030
# >Predicted=1.030, Expected=1.032
# >Predicted=1.032, Expected=1.027
# >Predicted=1.027, Expected=1.031
# >Predicted=1.031, Expected=1.044
# >Predicted=1.044, Expected=1.037
# >Predicted=1.037, Expected=1.037
# >Predicted=1.037, Expected=1.038
# >Predicted=1.038, Expected=1.037
# >Predicted=1.037, Expected=1.041
# >Predicted=1.041, Expected=1.035
# >Predicted=1.035, Expected=1.033
# >Predicted=1.033, Expected=1.037
# >Predicted=1.037, Expected=1.028
# >Predicted=1.028, Expected=1.034
# >Predicted=1.034, Expected=1.039
# >Predicted=1.039, Expected=1.047
# >Predicted=1.047, Expected=1.042
# >Predicted=1.042, Expected=1.034
# >Predicted=1.034, Expected=1.031
# >Predicted=1.031, Expected=1.025
# >Predicted=1.025, Expected=1.019
# >Predicted=1.019, Expected=1.018
# >Predicted=1.018, Expected=1.021
# >Predicted=1.021, Expected=1.012
# >Predicted=1.012, Expected=1.008
# >Predicted=1.008, Expected=1.011
# >Predicted=1.011, Expected=1.004
# >Predicted=1.004, Expected=0.999
# >Predicted=0.999, Expected=0.996
# >Predicted=0.996, Expected=0.992
# >Predicted=0.992, Expected=0.994
# >Predicted=0.994, Expected=0.982
# >Predicted=0.982, Expected=0.984
# >Predicted=0.984, Expected=0.984
# >Predicted=0.984, Expected=0.987
# >Predicted=0.987, Expected=0.984
# >Predicted=0.984, Expected=0.973
# >Predicted=0.973, Expected=0.972
# >Predicted=0.972, Expected=0.978
# >Predicted=0.978, Expected=0.976
# >Predicted=0.976, Expected=0.985
# >Predicted=0.985, Expected=0.982
# >Predicted=0.982, Expected=0.973
# >Predicted=0.973, Expected=0.973
# >Predicted=0.973, Expected=0.968
# >Predicted=0.968, Expected=0.971
# >Predicted=0.971, Expected=0.971
# >Predicted=0.971, Expected=0.973
# >Predicted=0.973, Expected=0.990
# >Predicted=0.990, Expected=0.993
# >Predicted=0.993, Expected=0.989
# >Predicted=0.989, Expected=0.991
# >Predicted=0.991, Expected=0.993
# >Predicted=0.993, Expected=0.998
# >Predicted=0.998, Expected=0.998
# >Predicted=0.998, Expected=1.006
# >Predicted=1.006, Expected=1.012
# >Predicted=1.012, Expected=1.019
# >Predicted=1.019, Expected=1.019
# >Predicted=1.019, Expected=1.006
# >Predicted=1.006, Expected=1.006
# >Predicted=1.006, Expected=1.006
# >Predicted=1.006, Expected=1.007
# >Predicted=1.007, Expected=0.999
# >Predicted=0.999, Expected=1.006
# >Predicted=1.006, Expected=1.007
# >Predicted=1.007, Expected=1.001
# >Predicted=1.001, Expected=1.024
# >Predicted=1.024, Expected=1.024
# >Predicted=1.024, Expected=1.024
# >Predicted=1.024, Expected=1.024
# >Predicted=1.024, Expected=1.028
# >Predicted=1.028, Expected=1.028
# >Predicted=1.028, Expected=1.029
# >Predicted=1.029, Expected=1.019
# >Predicted=1.019, Expected=1.021
# >Predicted=1.021, Expected=1.020
# >Predicted=1.020, Expected=1.021
# >Predicted=1.021, Expected=1.026
# >Predicted=1.026, Expected=1.014
# >Predicted=1.014, Expected=1.023
# >Predicted=1.023, Expected=1.024
# >Predicted=1.024, Expected=1.030
# >Predicted=1.030, Expected=1.036
# >Predicted=1.036, Expected=1.042
# >Predicted=1.042, Expected=1.037
# >Predicted=1.037, Expected=1.038
# >Predicted=1.038, Expected=1.038
# >Predicted=1.038, Expected=1.027
# >Predicted=1.027, Expected=1.023
# >Predicted=1.023, Expected=1.032
# >Predicted=1.032, Expected=1.039
# >Predicted=1.039, Expected=1.047
# >Predicted=1.047, Expected=1.049
# >Predicted=1.049, Expected=1.052
# >Predicted=1.052, Expected=1.053
# >Predicted=1.053, Expected=1.045
# >Predicted=1.045, Expected=1.055
# >Predicted=1.055, Expected=1.057
# >Predicted=1.057, Expected=1.057
# >Predicted=1.057, Expected=1.058
# >Predicted=1.058, Expected=1.056
# >Predicted=1.056, Expected=1.057
# >Predicted=1.057, Expected=1.057
# >Predicted=1.057, Expected=1.056
# >Predicted=1.056, Expected=1.051
# >Predicted=1.051, Expected=1.050
# >Predicted=1.050, Expected=1.050
# >Predicted=1.050, Expected=1.052
# >Predicted=1.052, Expected=1.043
# >Predicted=1.043, Expected=1.042
# >Predicted=1.042, Expected=1.042
# >Predicted=1.042, Expected=1.045
# >Predicted=1.045, Expected=1.049
# >Predicted=1.049, Expected=1.044
# >Predicted=1.044, Expected=1.045
# >Predicted=1.045, Expected=1.042
# >Predicted=1.042, Expected=1.038
# >Predicted=1.038, Expected=1.038
# >Predicted=1.038, Expected=1.037
# >Predicted=1.037, Expected=1.029
# >Predicted=1.029, Expected=1.033
# >Predicted=1.033, Expected=1.032
# >Predicted=1.032, Expected=1.025
# >Predicted=1.025, Expected=1.022
# >Predicted=1.022, Expected=1.019
# >Predicted=1.019, Expected=1.030
# >Predicted=1.030, Expected=1.039
# >Predicted=1.039, Expected=1.035
# >Predicted=1.035, Expected=1.045
# >Predicted=1.045, Expected=1.046
# >Predicted=1.046, Expected=1.053
# >Predicted=1.053, Expected=1.056
# >Predicted=1.056, Expected=1.046
# >Predicted=1.046, Expected=1.044
# >Predicted=1.044, Expected=1.048
# >Predicted=1.048, Expected=1.042
# >Predicted=1.042, Expected=1.046
# >Predicted=1.046, Expected=1.041
# >Predicted=1.041, Expected=1.042
# >Predicted=1.042, Expected=1.036
# >Predicted=1.036, Expected=1.045
# >Predicted=1.045, Expected=1.039
# >Predicted=1.039, Expected=1.038
# >Predicted=1.038, Expected=1.027
# >Predicted=1.027, Expected=1.021
# >Predicted=1.021, Expected=1.027
# >Predicted=1.027, Expected=1.020
# >Predicted=1.020, Expected=1.018
# >Predicted=1.018, Expected=1.021
# >Predicted=1.021, Expected=1.019
# >Predicted=1.019, Expected=1.023
# >Predicted=1.023, Expected=1.028
# >Predicted=1.028, Expected=1.022
# >Predicted=1.022, Expected=1.023
# >Predicted=1.023, Expected=1.024
# >Predicted=1.024, Expected=1.025
# >Predicted=1.025, Expected=1.027
# >Predicted=1.027, Expected=1.037
# >Predicted=1.037, Expected=1.039
# >Predicted=1.039, Expected=1.033
# >Predicted=1.033, Expected=1.033
# >Predicted=1.033, Expected=1.032
# >Predicted=1.032, Expected=1.026
# >Predicted=1.026, Expected=1.035
# >Predicted=1.035, Expected=1.035
# >Predicted=1.035, Expected=1.035
# >Predicted=1.035, Expected=1.033
# >Predicted=1.033, Expected=1.037
# >Predicted=1.037, Expected=1.038
# >Predicted=1.038, Expected=1.040
# >Predicted=1.040, Expected=1.037
# >Predicted=1.037, Expected=1.034
# >Predicted=1.034, Expected=1.037
# >Predicted=1.037, Expected=1.044
# >Predicted=1.044, Expected=1.041
# >Predicted=1.041, Expected=1.043
# >Predicted=1.043, Expected=1.039
# >Predicted=1.039, Expected=1.039
# >Predicted=1.039, Expected=1.042
# >Predicted=1.042, Expected=1.043
# >Predicted=1.043, Expected=1.039
# >Predicted=1.039, Expected=1.031
# >Predicted=1.031, Expected=1.031
# >Predicted=1.031, Expected=1.034
# >Predicted=1.034, Expected=1.040
# >Predicted=1.040, Expected=1.038
# >Predicted=1.038, Expected=1.034
# >Predicted=1.034, Expected=1.038
# >Predicted=1.038, Expected=1.045
# >Predicted=1.045, Expected=1.046
# >Predicted=1.046, Expected=1.045
# >Predicted=1.045, Expected=1.046
# >Predicted=1.046, Expected=1.047
# >Predicted=1.047, Expected=1.043
# >Predicted=1.043, Expected=1.042
# >Predicted=1.042, Expected=1.043
# >Predicted=1.043, Expected=1.044
# >Predicted=1.044, Expected=1.043
# >Predicted=1.043, Expected=1.048
# >Predicted=1.048, Expected=1.045
# >Predicted=1.045, Expected=1.049
# >Predicted=1.049, Expected=1.049
# >Predicted=1.049, Expected=1.049
# >Predicted=1.049, Expected=1.049
# >Predicted=1.049, Expected=1.049
# >Predicted=1.049, Expected=1.052
# >Predicted=1.052, Expected=1.053
# >Predicted=1.053, Expected=1.055
# >Predicted=1.055, Expected=1.056
# >Predicted=1.056, Expected=1.056
# >Predicted=1.056, Expected=1.055
# >Predicted=1.055, Expected=1.053
# >Predicted=1.053, Expected=1.050
# >Predicted=1.050, Expected=1.048
# >Predicted=1.048, Expected=1.042
# >Predicted=1.042, Expected=1.040
# >Predicted=1.040, Expected=1.037
# >Predicted=1.037, Expected=1.037
# >Predicted=1.037, Expected=1.035
# >Predicted=1.035, Expected=1.036
# >Predicted=1.036, Expected=1.038
# >Predicted=1.038, Expected=1.037
# >Predicted=1.037, Expected=1.039
# >Predicted=1.039, Expected=1.040
# >Predicted=1.040, Expected=1.049
# >Predicted=1.049, Expected=1.051
# >Predicted=1.051, Expected=1.046
# >Predicted=1.046, Expected=1.048
# >Predicted=1.048, Expected=1.048
# >Predicted=1.048, Expected=1.048
# >Predicted=1.048, Expected=1.049
# >Predicted=1.049, Expected=1.052
# >Predicted=1.052, Expected=1.057
# >Predicted=1.057, Expected=1.054
# >Predicted=1.054, Expected=1.053
# >Predicted=1.053, Expected=1.053
# >Predicted=1.053, Expected=1.056
# >Predicted=1.056, Expected=1.056
# >Predicted=1.056, Expected=1.056
# >Predicted=1.056, Expected=1.054
# >Predicted=1.054, Expected=1.049
# >Predicted=1.049, Expected=1.051
# >Predicted=1.051, Expected=1.051
# >Predicted=1.051, Expected=1.051
# >Predicted=1.051, Expected=1.056
# >Predicted=1.056, Expected=1.055
# >Predicted=1.055, Expected=1.047
# >Predicted=1.047, Expected=1.042
# >Predicted=1.042, Expected=1.042
# >Predicted=1.042, Expected=1.042
# >Predicted=1.042, Expected=1.040
# >Predicted=1.040, Expected=1.047
# >Predicted=1.047, Expected=1.042
# >Predicted=1.042, Expected=1.043
# >Predicted=1.043, Expected=1.042
# >Predicted=1.042, Expected=1.040
# >Predicted=1.040, Expected=1.041
# >Predicted=1.041, Expected=1.043
# >Predicted=1.043, Expected=1.039
# >Predicted=1.039, Expected=1.032
# >Predicted=1.032, Expected=1.029
# >Predicted=1.029, Expected=1.032
# >Predicted=1.032, Expected=1.032
# >Predicted=1.032, Expected=1.032
# >Predicted=1.032, Expected=1.029
# >Predicted=1.029, Expected=1.031
# >Predicted=1.031, Expected=1.034
# >Predicted=1.034, Expected=1.035
# >Predicted=1.035, Expected=1.030
# >Predicted=1.030, Expected=1.030
# >Predicted=1.030, Expected=1.030
# >Predicted=1.030, Expected=1.030
# >Predicted=1.030, Expected=1.035
# >Predicted=1.035, Expected=1.028
# >Predicted=1.028, Expected=1.025
# >Predicted=1.025, Expected=1.031
# >Predicted=1.031, Expected=1.032
# >Predicted=1.032, Expected=1.033
# >Predicted=1.033, Expected=1.029
# >Predicted=1.029, Expected=1.021
# >Predicted=1.021, Expected=1.020
# >Predicted=1.020, Expected=1.024
# >Predicted=1.024, Expected=1.021
# >Predicted=1.021, Expected=1.021
# >Predicted=1.021, Expected=1.016
# >Predicted=1.016, Expected=1.024
# >Predicted=1.024, Expected=1.025
# >Predicted=1.025, Expected=1.026
# >Predicted=1.026, Expected=1.022
# >Predicted=1.022, Expected=1.023
# >Predicted=1.023, Expected=1.024
# >Predicted=1.024, Expected=1.026
# >Predicted=1.026, Expected=1.032
# >Predicted=1.032, Expected=1.031
# >Predicted=1.031, Expected=1.040
# >Predicted=1.040, Expected=1.040
# >Predicted=1.040, Expected=1.041
# >Predicted=1.041, Expected=1.041
# >Predicted=1.041, Expected=1.040
# >Predicted=1.040, Expected=1.037
# >Predicted=1.037, Expected=1.039
# >Predicted=1.039, Expected=1.044
# >Predicted=1.044, Expected=1.044
# >Predicted=1.044, Expected=1.044
# >Predicted=1.044, Expected=1.044
# >Predicted=1.044, Expected=1.045
# >Predicted=1.045, Expected=1.048
# >Predicted=1.048, Expected=1.044
# >Predicted=1.044, Expected=1.041
# >Predicted=1.041, Expected=1.041
# >Predicted=1.041, Expected=1.041
# >Predicted=1.041, Expected=1.041
# >Predicted=1.041, Expected=1.043
# >Predicted=1.043, Expected=1.045
# >Predicted=1.045, Expected=1.048
# >Predicted=1.048, Expected=1.040
# >Predicted=1.040, Expected=1.038
# >Predicted=1.038, Expected=1.043
# >Predicted=1.043, Expected=1.038
# >Predicted=1.038, Expected=1.040
# >Predicted=1.040, Expected=1.049
# >Predicted=1.049, Expected=1.054
# >Predicted=1.054, Expected=1.055
# >Predicted=1.055, Expected=1.051
# >Predicted=1.051, Expected=1.050
# >Predicted=1.050, Expected=1.051
# >Predicted=1.051, Expected=1.038
# >Predicted=1.038, Expected=1.039
# >Predicted=1.039, Expected=1.030
# >Predicted=1.030, Expected=1.030
# >Predicted=1.030, Expected=1.029
# >Predicted=1.029, Expected=1.029
# >Predicted=1.029, Expected=1.028
# >Predicted=1.028, Expected=1.026
# >Predicted=1.026, Expected=1.025
# >Predicted=1.025, Expected=1.026
# >Predicted=1.026, Expected=1.031
# >Predicted=1.031, Expected=1.028
# >Predicted=1.028, Expected=1.028
# >Predicted=1.028, Expected=1.028
# >Predicted=1.028, Expected=1.035
# >Predicted=1.035, Expected=1.036
# >Predicted=1.036, Expected=1.029
# >Predicted=1.029, Expected=1.026
# >Predicted=1.026, Expected=1.031
# >Predicted=1.031, Expected=1.032
# >Predicted=1.032, Expected=1.026
# >Predicted=1.026, Expected=1.025
# >Predicted=1.025, Expected=1.018
# >Predicted=1.018, Expected=1.018
# >Predicted=1.018, Expected=1.018
# >Predicted=1.018, Expected=1.002
# >Predicted=1.002, Expected=1.001
# >Predicted=1.001, Expected=1.001
# >Predicted=1.001, Expected=0.994
# >Predicted=0.994, Expected=0.989
# >Predicted=0.989, Expected=0.988
# >Predicted=0.988, Expected=0.984
# >Predicted=0.984, Expected=0.974
# >Predicted=0.974, Expected=0.973
# >Predicted=0.973, Expected=0.973
# >Predicted=0.973, Expected=0.981
# >Predicted=0.981, Expected=0.982
# >Predicted=0.982, Expected=0.969
# >Predicted=0.969, Expected=0.974
# >Predicted=0.974, Expected=0.964
# >Predicted=0.964, Expected=0.965
# >Predicted=0.965, Expected=0.967
# >Predicted=0.967, Expected=0.963
# >Predicted=0.963, Expected=0.964
# >Predicted=0.964, Expected=0.963
# >Predicted=0.963, Expected=0.967
# >Predicted=0.967, Expected=0.960
# >Predicted=0.960, Expected=0.979
# >Predicted=0.979, Expected=0.962
# >Predicted=0.962, Expected=0.953
# >Predicted=0.953, Expected=0.960
# >Predicted=0.960, Expected=0.948
# >Predicted=0.948, Expected=0.949
# >Predicted=0.949, Expected=0.950
# >Predicted=0.950, Expected=0.947
# >Predicted=0.947, Expected=0.942
# >Predicted=0.942, Expected=0.950
# >Predicted=0.950, Expected=0.960
# >Predicted=0.960, Expected=0.959
# >Predicted=0.959, Expected=0.957
# >Predicted=0.957, Expected=0.957
# >Predicted=0.957, Expected=0.954
# >Predicted=0.954, Expected=0.950
# >Predicted=0.950, Expected=0.954
# >Predicted=0.954, Expected=0.920
# >Predicted=0.920, Expected=0.923
# >Predicted=0.923, Expected=0.927
# >Predicted=0.927, Expected=0.927
# >Predicted=0.927, Expected=0.927
# >Predicted=0.927, Expected=0.928
# >Predicted=0.928, Expected=0.914
# >Predicted=0.914, Expected=0.914
# >Predicted=0.914, Expected=0.914
# >Predicted=0.914, Expected=0.923
# >Predicted=0.923, Expected=0.914
# >Predicted=0.914, Expected=0.907
# >Predicted=0.907, Expected=0.916
# >Predicted=0.916, Expected=0.906
# >Predicted=0.906, Expected=0.907
# >Predicted=0.907, Expected=0.907
# >Predicted=0.907, Expected=0.912
# >Predicted=0.912, Expected=0.917
# >Predicted=0.917, Expected=0.915
# >Predicted=0.915, Expected=0.914
# >Predicted=0.914, Expected=0.905
# >Predicted=0.905, Expected=0.905
# >Predicted=0.905, Expected=0.905
# >Predicted=0.905, Expected=0.909
# >Predicted=0.909, Expected=0.924
# >Predicted=0.924, Expected=0.923
# >Predicted=0.923, Expected=0.917
# >Predicted=0.917, Expected=0.919
# >Predicted=0.919, Expected=0.917
# >Predicted=0.917, Expected=0.919
# >Predicted=0.919, Expected=0.925
# >Predicted=0.925, Expected=0.929
# >Predicted=0.929, Expected=0.915
# >Predicted=0.915, Expected=0.923
# >Predicted=0.923, Expected=0.925
# >Predicted=0.925, Expected=0.926
# >Predicted=0.926, Expected=0.926
# >Predicted=0.926, Expected=0.919
# >Predicted=0.919, Expected=0.906
# >Predicted=0.906, Expected=0.897
# >Predicted=0.897, Expected=0.894
# >Predicted=0.894, Expected=0.892
# >Predicted=0.892, Expected=0.891
# >Predicted=0.891, Expected=0.891
# >Predicted=0.891, Expected=0.891
# >Predicted=0.891, Expected=0.899
# >Predicted=0.899, Expected=0.900
# >Predicted=0.900, Expected=0.912
# >Predicted=0.912, Expected=0.920
# >Predicted=0.920, Expected=0.919
# >Predicted=0.919, Expected=0.919
# >Predicted=0.919, Expected=0.915
# >Predicted=0.915, Expected=0.909
# >Predicted=0.909, Expected=0.913
# >Predicted=0.913, Expected=0.913
# >Predicted=0.913, Expected=0.918
# >Predicted=0.918, Expected=0.918
# >Predicted=0.918, Expected=0.918
# >Predicted=0.918, Expected=0.912
# >Predicted=0.912, Expected=0.909
# >Predicted=0.909, Expected=0.903
# >Predicted=0.903, Expected=0.903
# >Predicted=0.903, Expected=0.903
# >Predicted=0.903, Expected=0.903
# >Predicted=0.903, Expected=0.903
# >Predicted=0.903, Expected=0.902
# >Predicted=0.902, Expected=0.897
# >Predicted=0.897, Expected=0.894
# >Predicted=0.894, Expected=0.893
# >Predicted=0.893, Expected=0.890
# >Predicted=0.890, Expected=0.890
# >Predicted=0.890, Expected=0.890
# >Predicted=0.890, Expected=0.898
# >Predicted=0.898, Expected=0.905
# >Predicted=0.905, Expected=0.917
# >Predicted=0.917, Expected=0.912
# >Predicted=0.912, Expected=0.919
# >Predicted=0.919, Expected=0.919
# >Predicted=0.919, Expected=0.919
# >Predicted=0.919, Expected=0.924
# >Predicted=0.924, Expected=0.931
# >Predicted=0.931, Expected=0.933
# >Predicted=0.933, Expected=0.926
# >Predicted=0.926, Expected=0.925
# >Predicted=0.925, Expected=0.925
# >Predicted=0.925, Expected=0.925
# >Predicted=0.925, Expected=0.932
# >Predicted=0.932, Expected=0.935
# >Predicted=0.935, Expected=0.937
# >Predicted=0.937, Expected=0.943
# >Predicted=0.943, Expected=0.942
# >Predicted=0.942, Expected=0.939
# >Predicted=0.939, Expected=0.939
# >Predicted=0.939, Expected=0.944
# >Predicted=0.944, Expected=0.941
# >Predicted=0.941, Expected=0.937
# >Predicted=0.937, Expected=0.935
# >Predicted=0.935, Expected=0.932
# >Predicted=0.932, Expected=0.931
# >Predicted=0.931, Expected=0.932
# >Predicted=0.932, Expected=0.933
# >Predicted=0.933, Expected=0.939
# >Predicted=0.939, Expected=0.937
# >Predicted=0.937, Expected=0.941
# >Predicted=0.941, Expected=0.943
# >Predicted=0.943, Expected=0.943
# >Predicted=0.943, Expected=0.943
# >Predicted=0.943, Expected=0.944
# >Predicted=0.944, Expected=0.943
# >Predicted=0.943, Expected=0.943
# >Predicted=0.943, Expected=0.946
# >Predicted=0.946, Expected=0.947
# >Predicted=0.947, Expected=0.947
# >Predicted=0.947, Expected=0.947
# >Predicted=0.947, Expected=0.948
# >Predicted=0.948, Expected=0.952
# >Predicted=0.952, Expected=0.954
# >Predicted=0.954, Expected=0.964
# >Predicted=0.964, Expected=0.967
# >Predicted=0.967, Expected=0.967
# >Predicted=0.967, Expected=0.968
# >Predicted=0.968, Expected=0.966
# >Predicted=0.966, Expected=0.971
# >Predicted=0.971, Expected=0.962
# >Predicted=0.962, Expected=0.961
# >Predicted=0.961, Expected=0.958
# >Predicted=0.958, Expected=0.959
# >Predicted=0.959, Expected=0.959
# >Predicted=0.959, Expected=0.958
# >Predicted=0.958, Expected=0.948
# >Predicted=0.948, Expected=0.949
# >Predicted=0.949, Expected=0.946
# >Predicted=0.946, Expected=0.944
# >Predicted=0.944, Expected=0.944
# >Predicted=0.944, Expected=0.943
# >Predicted=0.943, Expected=0.951
# >Predicted=0.951, Expected=0.949
# >Predicted=0.949, Expected=0.952
# >Predicted=0.952, Expected=0.947
# >Predicted=0.947, Expected=0.938
# >Predicted=0.938, Expected=0.938
# >Predicted=0.938, Expected=0.938
# >Predicted=0.938, Expected=0.935
# >Predicted=0.935, Expected=0.930
# >Predicted=0.930, Expected=0.933
# >Predicted=0.933, Expected=0.932
# >Predicted=0.932, Expected=0.936
# >Predicted=0.936, Expected=0.937
# >Predicted=0.937, Expected=0.937
# >Predicted=0.937, Expected=0.940
# >Predicted=0.940, Expected=0.941
# >Predicted=0.941, Expected=0.937
# >Predicted=0.937, Expected=0.925
# >Predicted=0.925, Expected=0.916
# >Predicted=0.916, Expected=0.917
# >Predicted=0.917, Expected=0.915
# >Predicted=0.915, Expected=0.915
# >Predicted=0.915, Expected=0.912
# >Predicted=0.912, Expected=0.908
# >Predicted=0.908, Expected=0.909
# >Predicted=0.909, Expected=0.912
# >Predicted=0.912, Expected=0.911
# >Predicted=0.911, Expected=0.911
# >Predicted=0.911, Expected=0.910
# >Predicted=0.910, Expected=0.912
# >Predicted=0.912, Expected=0.901
# >Predicted=0.901, Expected=0.907
# >Predicted=0.907, Expected=0.910
# >Predicted=0.910, Expected=0.910
# >Predicted=0.910, Expected=0.910
# >Predicted=0.910, Expected=0.909
# >Predicted=0.909, Expected=0.915
# >Predicted=0.915, Expected=0.906
# >Predicted=0.906, Expected=0.893
# >Predicted=0.893, Expected=0.896
# >Predicted=0.896, Expected=0.896
# >Predicted=0.896, Expected=0.896
# >Predicted=0.896, Expected=0.897
# >Predicted=0.897, Expected=0.890
# >Predicted=0.890, Expected=0.888
# >Predicted=0.888, Expected=0.886
# >Predicted=0.886, Expected=0.892
# >Predicted=0.892, Expected=0.893
# >Predicted=0.893, Expected=0.893
# >Predicted=0.893, Expected=0.894
# >Predicted=0.894, Expected=0.892
# >Predicted=0.892, Expected=0.892
# >Predicted=0.892, Expected=0.888
# >Predicted=0.888, Expected=0.888
# >Predicted=0.888, Expected=0.887
# >Predicted=0.887, Expected=0.887
# >Predicted=0.887, Expected=0.892
# >Predicted=0.892, Expected=0.893
# >Predicted=0.893, Expected=0.891
# >Predicted=0.891, Expected=0.892
# >Predicted=0.892, Expected=0.898
# >Predicted=0.898, Expected=0.894
# >Predicted=0.894, Expected=0.894
# >Predicted=0.894, Expected=0.895
# >Predicted=0.895, Expected=0.892
# >Predicted=0.892, Expected=0.891
# >Predicted=0.891, Expected=0.889
# >Predicted=0.889, Expected=0.898
# >Predicted=0.898, Expected=0.892
# >Predicted=0.892, Expected=0.900
# ...
# >Predicted=0.934, Expected=0.934
# >Predicted=0.934, Expected=0.934
# >Predicted=0.934, Expected=0.928
# >Predicted=0.928, Expected=0.934
# >Predicted=0.934, Expected=0.936
# >Predicted=0.936, Expected=0.938
# >Predicted=0.938, Expected=0.938
# >Predicted=0.938, Expected=0.929
# >Predicted=0.929, Expected=0.920
# >Predicted=0.920, Expected=0.916
# >Predicted=0.916, Expected=0.911
# >Predicted=0.911, Expected=0.905
# >Predicted=0.905, Expected=0.905
# >Predicted=0.905, Expected=0.903
# >Predicted=0.903, Expected=0.909
# >Predicted=0.909, Expected=0.909
# >Predicted=0.909, Expected=0.903
# >Predicted=0.903, Expected=0.898
# >Predicted=0.898, Expected=0.893
# >Predicted=0.893, Expected=0.893
# >Predicted=0.893, Expected=0.893
# >Predicted=0.893, Expected=0.887
# >Predicted=0.887, Expected=0.884
# >Predicted=0.884, Expected=0.879
# >Predicted=0.879, Expected=0.876
# >Predicted=0.876, Expected=0.877
# >Predicted=0.877, Expected=0.877
# >Predicted=0.877, Expected=0.873
# >Predicted=0.873, Expected=0.874
# >Predicted=0.874, Expected=0.872
# >Predicted=0.872, Expected=0.867
# >Predicted=0.867, Expected=0.867
# >Predicted=0.867, Expected=0.867
# >Predicted=0.867, Expected=0.874
# >Predicted=0.874, Expected=0.881
# >Predicted=0.881, Expected=0.881
# >Predicted=0.881, Expected=0.875
# >Predicted=0.875, Expected=0.878
# >Predicted=0.878, Expected=0.873
# >Predicted=0.873, Expected=0.869
# >Predicted=0.869, Expected=0.869
# >Predicted=0.869, Expected=0.876
# >Predicted=0.876, Expected=0.873
# >Predicted=0.873, Expected=0.880
# >Predicted=0.880, Expected=0.877
# >Predicted=0.877, Expected=0.877
# >Predicted=0.877, Expected=0.875
# >Predicted=0.875, Expected=0.875
# >Predicted=0.875, Expected=0.879
# >Predicted=0.879, Expected=0.880
# >Predicted=0.880, Expected=0.879
# >Predicted=0.879, Expected=0.876
# >Predicted=0.876, Expected=0.881
# >Predicted=0.881, Expected=0.879
# >Predicted=0.879, Expected=0.879
# >Predicted=0.879, Expected=0.881
# >Predicted=0.881, Expected=0.885
# >Predicted=0.885, Expected=0.889
# >Predicted=0.889, Expected=0.883
# >Predicted=0.883, Expected=0.880
# >Predicted=0.880, Expected=0.880
# >Predicted=0.880, Expected=0.880
# >Predicted=0.880, Expected=0.870
# >Predicted=0.870, Expected=0.873
# >Predicted=0.873, Expected=0.859
# >Predicted=0.859, Expected=0.858
# >Predicted=0.858, Expected=0.862
# >Predicted=0.862, Expected=0.863
# >Predicted=0.863, Expected=0.863
# >Predicted=0.863, Expected=0.863
# >Predicted=0.863, Expected=0.867
# >Predicted=0.867, Expected=0.874
# >Predicted=0.874, Expected=0.873
# >Predicted=0.873, Expected=0.873
# >Predicted=0.873, Expected=0.875
# >Predicted=0.875, Expected=0.876
# >Predicted=0.876, Expected=0.872
# >Predicted=0.872, Expected=0.872
# >Predicted=0.872, Expected=0.863
# >Predicted=0.863, Expected=0.861
# >Predicted=0.861, Expected=0.867
# >Predicted=0.867, Expected=0.867
# >Predicted=0.867, Expected=0.867
# >Predicted=0.867, Expected=0.862
# >Predicted=0.862, Expected=0.852
# >Predicted=0.852, Expected=0.853
# >Predicted=0.853, Expected=0.855
# >Predicted=0.855, Expected=0.852
# >Predicted=0.852, Expected=0.851
# >Predicted=0.851, Expected=0.851
# >Predicted=0.851, Expected=0.851
# >Predicted=0.851, Expected=0.845
# >Predicted=0.845, Expected=0.842
# >Predicted=0.842, Expected=0.841
# >Predicted=0.841, Expected=0.833
# >Predicted=0.833, Expected=0.833
# >Predicted=0.833, Expected=0.833
# >Predicted=0.833, Expected=0.830
# >Predicted=0.830, Expected=0.834
# >Predicted=0.834, Expected=0.830
# >Predicted=0.830, Expected=0.827
# >Predicted=0.827, Expected=0.826
# >Predicted=0.826, Expected=0.824
# >Predicted=0.824, Expected=0.824
# >Predicted=0.824, Expected=0.822
# >Predicted=0.822, Expected=0.822
# >Predicted=0.822, Expected=0.817
# >Predicted=0.817, Expected=0.817
# >Predicted=0.817, Expected=0.813
# >Predicted=0.813, Expected=0.814
# >Predicted=0.814, Expected=0.814
# >Predicted=0.814, Expected=0.814
# >Predicted=0.814, Expected=0.810
# >Predicted=0.810, Expected=0.811
# >Predicted=0.811, Expected=0.811
# >Predicted=0.811, Expected=0.811
# >Predicted=0.811, Expected=0.811
# >Predicted=0.811, Expected=0.811
# >Predicted=0.811, Expected=0.815
# >Predicted=0.815, Expected=0.820
# >Predicted=0.820, Expected=0.809
# >Predicted=0.809, Expected=0.809
# >Predicted=0.809, Expected=0.810
# >Predicted=0.810, Expected=0.812
# >Predicted=0.812, Expected=0.805
# >Predicted=0.805, Expected=0.813
# >Predicted=0.813, Expected=0.819
# >Predicted=0.819, Expected=0.820
# >Predicted=0.820, Expected=0.820
# >Predicted=0.820, Expected=0.816
# >Predicted=0.816, Expected=0.816
# >Predicted=0.816, Expected=0.816
# >Predicted=0.816, Expected=0.821
# >Predicted=0.821, Expected=0.820
# >Predicted=0.820, Expected=0.823
# >Predicted=0.823, Expected=0.823
# >Predicted=0.823, Expected=0.821
# >Predicted=0.821, Expected=0.818
# >Predicted=0.818, Expected=0.810
# >Predicted=0.810, Expected=0.810
# >Predicted=0.810, Expected=0.793
# >Predicted=0.793, Expected=0.792
# >Predicted=0.792, Expected=0.792
# >Predicted=0.792, Expected=0.793
# >Predicted=0.793, Expected=0.794
# >Predicted=0.794, Expected=0.797
# >Predicted=0.797, Expected=0.776
# >Predicted=0.776, Expected=0.776
# >Predicted=0.776, Expected=0.778
# >Predicted=0.778, Expected=0.778
# >Predicted=0.778, Expected=0.781
# >Predicted=0.781, Expected=0.773
# >Predicted=0.773, Expected=0.777
# >Predicted=0.777, Expected=0.779
# >Predicted=0.779, Expected=0.781
# >Predicted=0.781, Expected=0.780
# >Predicted=0.780, Expected=0.780
# >Predicted=0.780, Expected=0.782
# >Predicted=0.782, Expected=0.778
# >Predicted=0.778, Expected=0.771
# >Predicted=0.771, Expected=0.777
# >Predicted=0.777, Expected=0.777
# >Predicted=0.777, Expected=0.777
# >Predicted=0.777, Expected=0.777
# >Predicted=0.777, Expected=0.777
# >Predicted=0.777, Expected=0.781
# >Predicted=0.781, Expected=0.778
# >Predicted=0.778, Expected=0.781
# >Predicted=0.781, Expected=0.783
# >Predicted=0.783, Expected=0.784
# >Predicted=0.784, Expected=0.784
# >Predicted=0.784, Expected=0.781
# >Predicted=0.781, Expected=0.781
# >Predicted=0.781, Expected=0.789
# >Predicted=0.789, Expected=0.782
# >Predicted=0.782, Expected=0.781
# >Predicted=0.781, Expected=0.782
# >Predicted=0.782, Expected=0.782
# >Predicted=0.782, Expected=0.778
# >Predicted=0.778, Expected=0.784
# >Predicted=0.784, Expected=0.782
# >Predicted=0.782, Expected=0.777
# >Predicted=0.777, Expected=0.772
# >Predicted=0.772, Expected=0.772
# >Predicted=0.772, Expected=0.772
# >Predicted=0.772, Expected=0.771
# >Predicted=0.771, Expected=0.762
# >Predicted=0.762, Expected=0.758
# >Predicted=0.758, Expected=0.768
# >Predicted=0.768, Expected=0.764
# >Predicted=0.764, Expected=0.764
# >Predicted=0.764, Expected=0.764
# >Predicted=0.764, Expected=0.766
# >Predicted=0.766, Expected=0.761
# >Predicted=0.761, Expected=0.766
# >Predicted=0.766, Expected=0.763
# >Predicted=0.763, Expected=0.778
# >Predicted=0.778, Expected=0.777
# >Predicted=0.777, Expected=0.777
# >Predicted=0.777, Expected=0.786
# >Predicted=0.786, Expected=0.787
# >Predicted=0.787, Expected=0.784
# >Predicted=0.784, Expected=0.783
# >Predicted=0.783, Expected=0.776
# >Predicted=0.776, Expected=0.775
# >Predicted=0.775, Expected=0.775
# >Predicted=0.775, Expected=0.765
# >Predicted=0.765, Expected=0.762
# >Predicted=0.762, Expected=0.762
# >Predicted=0.762, Expected=0.757
# >Predicted=0.757, Expected=0.764
# >Predicted=0.764, Expected=0.763
# >Predicted=0.763, Expected=0.763
# >Predicted=0.763, Expected=0.763
# >Predicted=0.763, Expected=0.765
# >Predicted=0.765, Expected=0.770
# >Predicted=0.770, Expected=0.769
# >Predicted=0.769, Expected=0.768
# >Predicted=0.768, Expected=0.768
# >Predicted=0.768, Expected=0.768
# >Predicted=0.768, Expected=0.758
# >Predicted=0.758, Expected=0.763
# >Predicted=0.763, Expected=0.769
# >Predicted=0.769, Expected=0.781
# >Predicted=0.781, Expected=0.777
# >Predicted=0.777, Expected=0.778
# >Predicted=0.778, Expected=0.778
# >Predicted=0.778, Expected=0.771
# >Predicted=0.771, Expected=0.772
# >Predicted=0.772, Expected=0.778
# >Predicted=0.778, Expected=0.779
# >Predicted=0.779, Expected=0.782
# >Predicted=0.782, Expected=0.782
# >Predicted=0.782, Expected=0.782
# >Predicted=0.782, Expected=0.786
# >Predicted=0.786, Expected=0.802
# >Predicted=0.802, Expected=0.806
# >Predicted=0.806, Expected=0.790
# >Predicted=0.790, Expected=0.783
# >Predicted=0.783, Expected=0.785
# >Predicted=0.785, Expected=0.785
# >Predicted=0.785, Expected=0.785
# >Predicted=0.785, Expected=0.795
# >Predicted=0.795, Expected=0.797
# >Predicted=0.797, Expected=0.790
# >Predicted=0.790, Expected=0.793
# >Predicted=0.793, Expected=0.793
# >Predicted=0.793, Expected=0.793
# >Predicted=0.793, Expected=0.791
# >Predicted=0.791, Expected=0.798
# >Predicted=0.798, Expected=0.811
# >Predicted=0.811, Expected=0.808
# >Predicted=0.808, Expected=0.804
# >Predicted=0.804, Expected=0.803
# >Predicted=0.803, Expected=0.803
# >Predicted=0.803, Expected=0.799
# >Predicted=0.799, Expected=0.792
# >Predicted=0.792, Expected=0.788
# >Predicted=0.788, Expected=0.789
# >Predicted=0.789, Expected=0.782
# >Predicted=0.782, Expected=0.782
# >Predicted=0.782, Expected=0.782
# >Predicted=0.782, Expected=0.783
# >Predicted=0.783, Expected=0.774
# >Predicted=0.774, Expected=0.772
# >Predicted=0.772, Expected=0.765
# >Predicted=0.765, Expected=0.766
# >Predicted=0.766, Expected=0.764
# >Predicted=0.764, Expected=0.764
# >Predicted=0.764, Expected=0.761
# >Predicted=0.761, Expected=0.778
# >Predicted=0.778, Expected=0.778
# >Predicted=0.778, Expected=0.768
# >Predicted=0.768, Expected=0.762
# >Predicted=0.762, Expected=0.763
# >Predicted=0.763, Expected=0.763
# >Predicted=0.763, Expected=0.767
# >Predicted=0.767, Expected=0.767
# >Predicted=0.767, Expected=0.776
# >Predicted=0.776, Expected=0.773
# >Predicted=0.773, Expected=0.775
# >Predicted=0.775, Expected=0.773
# >Predicted=0.773, Expected=0.773
# >Predicted=0.773, Expected=0.776
# >Predicted=0.776, Expected=0.775
# >Predicted=0.775, Expected=0.767
# >Predicted=0.767, Expected=0.780
# >Predicted=0.780, Expected=0.777
# >Predicted=0.777, Expected=0.777
# >Predicted=0.777, Expected=0.777
# >Predicted=0.777, Expected=0.773
# >Predicted=0.773, Expected=0.773
# >Predicted=0.773, Expected=0.772
# >Predicted=0.772, Expected=0.775
# >Predicted=0.775, Expected=0.764
# >Predicted=0.764, Expected=0.765
# >Predicted=0.765, Expected=0.765
# >Predicted=0.765, Expected=0.771
# >Predicted=0.771, Expected=0.771
# >Predicted=0.771, Expected=0.766
# >Predicted=0.766, Expected=0.763
# >Predicted=0.763, Expected=0.752
# >Predicted=0.752, Expected=0.752
# >Predicted=0.752, Expected=0.751
# >Predicted=0.751, Expected=0.751
# >Predicted=0.751, Expected=0.743
# >Predicted=0.743, Expected=0.743
# >Predicted=0.743, Expected=0.743
# >Predicted=0.743, Expected=0.742
# >Predicted=0.742, Expected=0.745
# >Predicted=0.745, Expected=0.745
# >Predicted=0.745, Expected=0.740
# >Predicted=0.740, Expected=0.745
# >Predicted=0.745, Expected=0.737
# >Predicted=0.737, Expected=0.741
# >Predicted=0.741, Expected=0.738
# >Predicted=0.738, Expected=0.737
# >Predicted=0.737, Expected=0.737
# >Predicted=0.737, Expected=0.738
# >Predicted=0.738, Expected=0.744
# >Predicted=0.744, Expected=0.738
# >Predicted=0.738, Expected=0.737
# >Predicted=0.737, Expected=0.727
# >Predicted=0.727, Expected=0.727
# >Predicted=0.727, Expected=0.729
# >Predicted=0.729, Expected=0.729
# >Predicted=0.729, Expected=0.734
# >Predicted=0.734, Expected=0.732
# >Predicted=0.732, Expected=0.728
# >Predicted=0.728, Expected=0.732
# >Predicted=0.732, Expected=0.731
# >Predicted=0.731, Expected=0.731
# >Predicted=0.731, Expected=0.727
# >Predicted=0.727, Expected=0.739
# >Predicted=0.739, Expected=0.736
# >Predicted=0.736, Expected=0.735
# >Predicted=0.735, Expected=0.742
# >Predicted=0.742, Expected=0.742
# >Predicted=0.742, Expected=0.741
# >Predicted=0.741, Expected=0.741
# >Predicted=0.741, Expected=0.729
# >Predicted=0.729, Expected=0.738
# >Predicted=0.738, Expected=0.736
# >Predicted=0.736, Expected=0.738
# >Predicted=0.738, Expected=0.737
# >Predicted=0.737, Expected=0.737
# >Predicted=0.737, Expected=0.739
# >Predicted=0.739, Expected=0.733
# >Predicted=0.733, Expected=0.735
# >Predicted=0.735, Expected=0.735
# >Predicted=0.735, Expected=0.733
# >Predicted=0.733, Expected=0.732
# >Predicted=0.732, Expected=0.732
# >Predicted=0.732, Expected=0.721
# >Predicted=0.721, Expected=0.716
# >Predicted=0.716, Expected=0.709
# >Predicted=0.709, Expected=0.716
# >Predicted=0.716, Expected=0.716
# >Predicted=0.716, Expected=0.717
# >Predicted=0.717, Expected=0.717
# >Predicted=0.717, Expected=0.712
# >Predicted=0.712, Expected=0.704
# >Predicted=0.704, Expected=0.704
# >Predicted=0.704, Expected=0.701
# >Predicted=0.701, Expected=0.692
# >Predicted=0.692, Expected=0.691
# >Predicted=0.691, Expected=0.691
# >Predicted=0.691, Expected=0.693
# >Predicted=0.693, Expected=0.703
# >Predicted=0.703, Expected=0.702
# >Predicted=0.702, Expected=0.709
# >Predicted=0.709, Expected=0.708
# >Predicted=0.708, Expected=0.709
# >Predicted=0.709, Expected=0.713
# >Predicted=0.713, Expected=0.714
# >Predicted=0.714, Expected=0.712
# >Predicted=0.712, Expected=0.719
# >Predicted=0.719, Expected=0.717
# >Predicted=0.717, Expected=0.723
# >Predicted=0.723, Expected=0.724
# >Predicted=0.724, Expected=0.719
# >Predicted=0.719, Expected=0.713
# >Predicted=0.713, Expected=0.709
# >Predicted=0.709, Expected=0.701
# >Predicted=0.701, Expected=0.701
# >Predicted=0.701, Expected=0.702
# >Predicted=0.702, Expected=0.703
# >Predicted=0.703, Expected=0.703
# >Predicted=0.703, Expected=0.699
# >Predicted=0.699, Expected=0.700
# >Predicted=0.700, Expected=0.701
# >Predicted=0.701, Expected=0.702
# >Predicted=0.702, Expected=0.703
# >Predicted=0.703, Expected=0.707
# >Predicted=0.707, Expected=0.707
# >Predicted=0.707, Expected=0.708
# >Predicted=0.708, Expected=0.715
# >Predicted=0.715, Expected=0.721
# >Predicted=0.721, Expected=0.723
# >Predicted=0.723, Expected=0.733
# >Predicted=0.733, Expected=0.734
# >Predicted=0.734, Expected=0.734
# >Predicted=0.734, Expected=0.737
# >Predicted=0.737, Expected=0.728
# >Predicted=0.728, Expected=0.727
# >Predicted=0.727, Expected=0.733
# >Predicted=0.733, Expected=0.727
# >Predicted=0.727, Expected=0.726
# >Predicted=0.726, Expected=0.726
# >Predicted=0.726, Expected=0.726
# >Predicted=0.726, Expected=0.727
# >Predicted=0.727, Expected=0.723
# >Predicted=0.723, Expected=0.722
# >Predicted=0.722, Expected=0.722
# >Predicted=0.722, Expected=0.722
# >Predicted=0.722, Expected=0.722
# >Predicted=0.722, Expected=0.726
# >Predicted=0.726, Expected=0.721
# >Predicted=0.721, Expected=0.714
# >Predicted=0.714, Expected=0.708
# >Predicted=0.708, Expected=0.714
# >Predicted=0.714, Expected=0.714
# >Predicted=0.714, Expected=0.714
# >Predicted=0.714, Expected=0.714
# >Predicted=0.714, Expected=0.717
# >Predicted=0.717, Expected=0.714
# >Predicted=0.714, Expected=0.715
# >Predicted=0.715, Expected=0.703
# >Predicted=0.703, Expected=0.704
# >Predicted=0.704, Expected=0.704
# >Predicted=0.704, Expected=0.705
# >Predicted=0.705, Expected=0.703
# >Predicted=0.703, Expected=0.706
# >Predicted=0.706, Expected=0.712
# >Predicted=0.712, Expected=0.711
# >Predicted=0.711, Expected=0.713
# >Predicted=0.713, Expected=0.713
# >Predicted=0.713, Expected=0.709
# >Predicted=0.709, Expected=0.712
# >Predicted=0.712, Expected=0.708
# >Predicted=0.708, Expected=0.721
# >Predicted=0.721, Expected=0.723
# >Predicted=0.723, Expected=0.724
# >Predicted=0.724, Expected=0.724
# >Predicted=0.724, Expected=0.719
# >Predicted=0.719, Expected=0.724
# >Predicted=0.724, Expected=0.725
# >Predicted=0.725, Expected=0.723
# >Predicted=0.723, Expected=0.719
# >Predicted=0.719, Expected=0.720
# >Predicted=0.720, Expected=0.720
# >Predicted=0.720, Expected=0.724
# >Predicted=0.724, Expected=0.732
# >Predicted=0.732, Expected=0.731
# >Predicted=0.731, Expected=0.731
# >Predicted=0.731, Expected=0.735
# >Predicted=0.735, Expected=0.734
# >Predicted=0.734, Expected=0.734
# >Predicted=0.734, Expected=0.727
# >Predicted=0.727, Expected=0.721
# >Predicted=0.721, Expected=0.721
# >Predicted=0.721, Expected=0.730
# >Predicted=0.730, Expected=0.722
# >Predicted=0.722, Expected=0.719
# >Predicted=0.719, Expected=0.719
# >Predicted=0.719, Expected=0.725
# >Predicted=0.725, Expected=0.717
# >Predicted=0.717, Expected=0.721
# >Predicted=0.721, Expected=0.711
# >Predicted=0.711, Expected=0.720
# >Predicted=0.720, Expected=0.717
# >Predicted=0.717, Expected=0.717
# >Predicted=0.717, Expected=0.717
# >Predicted=0.717, Expected=0.723
# >Predicted=0.723, Expected=0.722
# >Predicted=0.722, Expected=0.727
# >Predicted=0.727, Expected=0.727
# >Predicted=0.727, Expected=0.728
# >Predicted=0.728, Expected=0.728
# >Predicted=0.728, Expected=0.726
# >Predicted=0.726, Expected=0.729
# >Predicted=0.729, Expected=0.728
# >Predicted=0.728, Expected=0.728
# >Predicted=0.728, Expected=0.728
# RMSE: 0.025

# %% [markdown]
# **ARIMA Hyperparameters**

# %%
# grid search ARIMA parameters for a time series

import warnings
from pandas import read_csv
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt


# evaluate an ARIMA model for a given order (p,d,q) and return RMSE
def evaluate_arima_model(X, arima_order):
# prepare training dataset
    numeric_data = X.select_dtypes(include=['float64', 'int64'])
    X = numeric_data.values
    X = X.astype('float32')
    train_size = int(len(X) * 0.50)
    train, test = X[0:train_size], X[train_size:]
    history = [x for x in train]
# make predictions
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=arima_order)
# model_fit = model.fit(disp=0)
        model_fit = model.fit(disp=0)
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(test[t])
# calculate out of sample error
    rmse = sqrt(mean_squared_error(test, predictions))
    return rmse

# %%
rmse
# Out:
# 0.02535658381326554

# %% [markdown]
# **Grid Search for p,d,q values**

# %%
# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float('inf'), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    rmse = evaluate_arima_model(train, order)
                    if rmse < best_score:
                        best_score, best_cfg = rmse, order
                    print('ARIMA%s RMSE=%.3f' % (order,rmse))
                except:
                    continue
    print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# %%
# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
    # Extract numeric columns before casting to float32
    numeric_data = dataset.select_dtypes(include=['float64', 'int64'])
    dataset = numeric_data.values.astype('float32')
    best_score, best_cfg = float('inf'), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)

# %% [markdown]
# Build Model Based on the optimized values

# %%
# save finalized model to file
from pandas import read_csv
from statsmodels.tsa.arima_model import ARIMA
import numpy

# %%
# load data
train = read_csv('dataset.csv', header=0, index_col=0, parse_dates=True)
# prepare data
# Keep X as the DataFrame to use select_dtypes
X = train
numeric_data = X.select_dtypes(include=['float64', 'int64'])
# Now extract the values from the numeric DataFrame
X = numeric_data.values
X = X.astype('float32')

# %%
# fit model
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_predict # Import plot_predict function
import matplotlib.pyplot as plt # Import matplotlib for plotting

model = ARIMA(X, order=(2,1,0))
model_fit = model.fit()
forecast=model_fit.forecast(steps=10)[0]

# Use the imported plot_predict function
fig, ax = plt.subplots()
plot_predict(model_fit, start=1, end=79, ax=ax)
plt.show()

# %% [markdown]
# Combine the train and test data and build the final model

# %%
# fit model
data = read_csv('exchange_rate.csv', header=0, index_col=0, parse_dates=True)
# Keep X as the DataFrame to use select_dtypes
X = train
numeric_data = X.select_dtypes(include=['float64', 'int64'])
# Now extract the values from the numeric DataFrame
X = numeric_data.values
X = X.astype('float32')

# %%
model = ARIMA(X, order=(2,1,0))
model_fit = model.fit()

# %%
forecast=model_fit.forecast(steps=10)[0]

# %%
# Import the plot_predict function
from statsmodels.graphics.tsaplots import plot_predict
import matplotlib.pyplot as plt

# Use the plot_predict function, passing in the fitted model
fig, ax = plt.subplots()
plot_predict(model_fit, start=1, end=80, ax=ax)
plt.show()
